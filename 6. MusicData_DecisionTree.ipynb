# %% [markdown]
# # **Decision Tree Model (By Nourhan Adel)**

# %% [markdown]
# ### **Import libraries**

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### **Load and inspect data**

# %%
pwd = os.getcwd()
data_path = os.path.join(pwd,'/content/Final_Data.csv')
data = pd.read_csv(data_path)
data.head()
# Out:
#            Artist                           Title  Label  \
# 0      The Weeknd                 Blinding Lights      1
# 1  Olivia Rodrigo                        Good 4 U      1
# 2  Olivia Rodrigo                 Drivers License      1
# 3       Lil Nas X  Montero (Call Me By Your Name)      1
# 4             BTS                          Butter      1
#
#                                     song_path  \
# 0                 popular/Blinding Lights.mp3
# 1                        popular/Good 4 U.mp3
# 2                 popular/Drivers License.mp3
# 3  popular/Montero (Call Me By Your Name).mp3
# 4                          popular/Butter.mp3
#
#                                        new_song_path  \
# 0  /content/drive/MyDrive/bill/popular/Blinding L...
# 1   /content/drive/MyDrive/bill/popular/Good 4 U.mp3
# 2  /content/drive/MyDrive/bill/popular/Drivers Li...
# 3  /content/drive/MyDrive/bill/popular/Montero (C...
# 4     /content/drive/MyDrive/bill/popular/Butter.mp3
#
#                                extracted_chorus_path  chroma_stft_kew_0  \
# 0                 chorus_extract/Blinding Lights.wav           0.476192
# 1                        chorus_extract/Good 4 U.wav           1.048281
# 2                 chorus_extract/Drivers License.wav           1.391406
# 3  chorus_extract/Montero (Call Me By Your Name).wav           0.898662
# 4                          chorus_extract/Butter.wav           0.299845
#
#    chroma_stft_min_0  chroma_stft_max_0  chroma_stft_std_0  ...  \
# 0           0.016697                1.0           0.290165  ...
# 1           0.006909                1.0           0.274690  ...
# 2           0.000700                1.0           0.307762  ...
# 3           0.002983                1.0           0.239849  ...
# 4           0.036609                1.0           0.334760  ...
#
#    tonnetz_mean_5  tonnetz_median_5  tonnetz_kurtosis_5  \
# 0        0.007436          0.000934           -0.539747
# 1       -0.010380         -0.011803            0.115312
# 2       -0.002966         -0.011493            0.486480
# 3       -0.013886         -0.021088            0.467516
# 4        0.006860          0.004859           -0.384372
#
#    zero_crossing_rate_kew_0  zero_crossing_rate_min_0  \
# 0                  1.466814                  0.037551
# 1                 -0.398137                  0.054286
# 2                  0.746785                  0.022630
# 3                  0.528719                  0.048934
# 4                  2.536822                  0.040181
#
#    zero_crossing_rate_max_0  zero_crossing_rate_std_0  \
# 0                  0.159229                  0.020931
# 1                  0.224626                  0.035255
# 2                  0.176054                  0.031968
# 3                  0.266757                  0.043461
# 4                  0.221769                  0.027223
#
#    zero_crossing_rate_mean_0  zero_crossing_rate_median_0  \
# 0                   0.082646                     0.079751
# 1                   0.147474                     0.157392
# 2                   0.076661                     0.065692
# 3                   0.143693                     0.137687
# 4                   0.095766                     0.090703
#
#    zero_crossing_rate_kurtosis_0
# 0                       3.242503
# 1                      -0.313862
# 2                      -0.147254
# 3                      -0.347516
# 4                       7.626171
#
# [5 rows x 524 columns]

# %%
len(data.keys())
# Out:
# 524

# %%
label = data['Label']

data = data.drop(['Artist',	'Title', 'song_path',	'new_song_path',	'extracted_chorus_path', 'Label'], axis=1)

# %%
len(data.keys())
# Out:
# 518

# %%
label[:5]
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Label, dtype: int64

# %% [markdown]
# ## **Use Correlation to drop the high correlated columns**
# Correlation is used to summarize the strength and direction of the linear association between two quantitative variables. It is denoted by r and values between -1 and +1. A positive value for r indicates a positive association, and a negative value for r indicates a negative association.

# %%
cor_matrix = data.corr().abs()
print(cor_matrix)
# Out:
#                                chroma_stft_kew_0  chroma_stft_min_0  \
# chroma_stft_kew_0                       1.000000           0.371227
# chroma_stft_min_0                       0.371227           1.000000
# chroma_stft_max_0                       0.007775           0.017458
# chroma_stft_std_0                       0.608770           0.081623
# chroma_stft_mean_0                      0.957253           0.495092
# ...                                          ...                ...
# zero_crossing_rate_max_0                0.079045           0.261665
# zero_crossing_rate_std_0                0.045875           0.274687
# zero_crossing_rate_mean_0               0.227831           0.151675
# zero_crossing_rate_median_0             0.243171           0.129835
# zero_crossing_rate_kurtosis_0           0.023809           0.023571
#
#                                chroma_stft_max_0  chroma_stft_std_0  \
# chroma_stft_kew_0                       0.007775           0.608770
# chroma_stft_min_0                       0.017458           0.081623
# chroma_stft_max_0                       1.000000           0.107553
# chroma_stft_std_0                       0.107553           1.000000
# chroma_stft_mean_0                      0.051734           0.562567
# ...                                          ...                ...
# zero_crossing_rate_max_0                0.098095           0.026015
# zero_crossing_rate_std_0                0.084236           0.125326
# zero_crossing_rate_mean_0               0.088060           0.114608
# zero_crossing_rate_median_0             0.084824           0.129071
# zero_crossing_rate_kurtosis_0           0.053854           0.029232
#
#                                chroma_stft_mean_0  chroma_stft_median_0  \
# chroma_stft_kew_0                        0.957253              0.917040
# chroma_stft_min_0                        0.495092              0.517531
# chroma_stft_max_0                        0.051734              0.028075
# chroma_stft_std_0                        0.562567              0.373904
# chroma_stft_mean_0                       1.000000              0.961666
# ...                                           ...                   ...
# zero_crossing_rate_max_0                 0.113519              0.129376
# zero_crossing_rate_std_0                 0.001702              0.019065
# zero_crossing_rate_mean_0                0.231609              0.235994
# zero_crossing_rate_median_0              0.241948              0.245211
# zero_crossing_rate_kurtosis_0            0.031767              0.035196
#
#                                chroma_stft_kurtosis_0  chroma_stft_kew_1  \
# chroma_stft_kew_0                            0.872730           0.529103
# chroma_stft_min_0                            0.227529           0.333706
# chroma_stft_max_0                            0.022703           0.030939
# chroma_stft_std_0                            0.753498           0.014716
# chroma_stft_mean_0                           0.782494           0.516246
# ...                                               ...                ...
# zero_crossing_rate_max_0                     0.013385           0.043337
# zero_crossing_rate_std_0                     0.069643           0.052896
# zero_crossing_rate_mean_0                    0.134317           0.171409
# zero_crossing_rate_median_0                  0.149730           0.184343
# zero_crossing_rate_kurtosis_0                0.009960           0.041947
#
#                                chroma_stft_min_1  chroma_stft_max_1  ...  \
# chroma_stft_kew_0                       0.308363           0.094832  ...
# chroma_stft_min_0                       0.809903           0.010094  ...
# chroma_stft_max_0                       0.025659           0.005727  ...
# chroma_stft_std_0                       0.129644           0.065915  ...
# chroma_stft_mean_0                      0.415525           0.076424  ...
# ...                                          ...                ...  ...
# zero_crossing_rate_max_0                0.247923           0.098008  ...
# zero_crossing_rate_std_0                0.285485           0.054041  ...
# zero_crossing_rate_mean_0               0.139273           0.080144  ...
# zero_crossing_rate_median_0             0.119664           0.065941  ...
# zero_crossing_rate_kurtosis_0           0.059902           0.054957  ...
#
#                                tonnetz_mean_5  tonnetz_median_5  \
# chroma_stft_kew_0                    0.090566          0.107142
# chroma_stft_min_0                    0.058051          0.045058
# chroma_stft_max_0                    0.004854          0.007240
# chroma_stft_std_0                    0.002471          0.008467
# chroma_stft_mean_0                   0.109993          0.117800
# ...                                       ...               ...
# zero_crossing_rate_max_0             0.012176          0.031299
# zero_crossing_rate_std_0             0.038456          0.054123
# zero_crossing_rate_mean_0            0.051424          0.005432
# zero_crossing_rate_median_0          0.056891          0.001487
# zero_crossing_rate_kurtosis_0        0.047813          0.045349
#
#                                tonnetz_kurtosis_5  zero_crossing_rate_kew_0  \
# chroma_stft_kew_0                        0.089319                  0.190798
# chroma_stft_min_0                        0.135096                  0.060600
# chroma_stft_max_0                        0.011509                  0.065172
# chroma_stft_std_0                        0.113215                  0.158057
# chroma_stft_mean_0                       0.044578                  0.160414
# ...                                           ...                       ...
# zero_crossing_rate_max_0                 0.081149                  0.189289
# zero_crossing_rate_std_0                 0.113560                  0.370523
# zero_crossing_rate_mean_0                0.023593                  0.363811
# zero_crossing_rate_median_0              0.033873                  0.448134
# zero_crossing_rate_kurtosis_0            0.009882                  0.217352
#
#                                zero_crossing_rate_min_0  \
# chroma_stft_kew_0                              0.227738
# chroma_stft_min_0                              0.023586
# chroma_stft_max_0                              0.028385
# chroma_stft_std_0                              0.173494
# chroma_stft_mean_0                             0.209077
# ...                                                 ...
# zero_crossing_rate_max_0                       0.491480
# zero_crossing_rate_std_0                       0.068530
# zero_crossing_rate_mean_0                      0.831051
# zero_crossing_rate_median_0                    0.832737
# zero_crossing_rate_kurtosis_0                  0.130876
#
#                                zero_crossing_rate_max_0  \
# chroma_stft_kew_0                              0.079045
# chroma_stft_min_0                              0.261665
# chroma_stft_max_0                              0.098095
# chroma_stft_std_0                              0.026015
# chroma_stft_mean_0                             0.113519
# ...                                                 ...
# zero_crossing_rate_max_0                       1.000000
# zero_crossing_rate_std_0                       0.775541
# zero_crossing_rate_mean_0                      0.756880
# zero_crossing_rate_median_0                    0.679963
# zero_crossing_rate_kurtosis_0                  0.201501
#
#                                zero_crossing_rate_std_0  \
# chroma_stft_kew_0                              0.045875
# chroma_stft_min_0                              0.274687
# chroma_stft_max_0                              0.084236
# chroma_stft_std_0                              0.125326
# chroma_stft_mean_0                             0.001702
# ...                                                 ...
# zero_crossing_rate_max_0                       0.775541
# zero_crossing_rate_std_0                       1.000000
# zero_crossing_rate_mean_0                      0.286494
# zero_crossing_rate_median_0                    0.196729
# zero_crossing_rate_kurtosis_0                  0.072649
#
#                                zero_crossing_rate_mean_0  \
# chroma_stft_kew_0                               0.227831
# chroma_stft_min_0                               0.151675
# chroma_stft_max_0                               0.088060
# chroma_stft_std_0                               0.114608
# chroma_stft_mean_0                              0.231609
# ...                                                  ...
# zero_crossing_rate_max_0                        0.756880
# zero_crossing_rate_std_0                        0.286494
# zero_crossing_rate_mean_0                       1.000000
# zero_crossing_rate_median_0                     0.989216
# zero_crossing_rate_kurtosis_0                   0.097521
#
#                                zero_crossing_rate_median_0  \
# chroma_stft_kew_0                                 0.243171
# chroma_stft_min_0                                 0.129835
# chroma_stft_max_0                                 0.084824
# chroma_stft_std_0                                 0.129071
# chroma_stft_mean_0                                0.241948
# ...                                                    ...
# zero_crossing_rate_max_0                          0.679963
# zero_crossing_rate_std_0                          0.196729
# zero_crossing_rate_mean_0                         0.989216
# zero_crossing_rate_median_0                       1.000000
# zero_crossing_rate_kurtosis_0                     0.072073
#
#                                zero_crossing_rate_kurtosis_0
# chroma_stft_kew_0                                   0.023809
# chroma_stft_min_0                                   0.023571
# chroma_stft_max_0                                   0.053854
# chroma_stft_std_0                                   0.029232
# chroma_stft_mean_0                                  0.031767
# ...                                                      ...
# zero_crossing_rate_max_0                            0.201501
# zero_crossing_rate_std_0                            0.072649
# zero_crossing_rate_mean_0                           0.097521
# zero_crossing_rate_median_0                         0.072073
# zero_crossing_rate_kurtosis_0                       1.000000
#
# [518 rows x 518 columns]

# %%
from sklearn.feature_selection import VarianceThreshold

constant_filter = VarianceThreshold(threshold=0.85)
constant_filter.fit(data)
# Out:
# VarianceThreshold(threshold=0.85)

# %%
len(data.columns[constant_filter.get_support()])
# Out:
# 198

# %%
constant_columns = [column for column in data.columns
                    if column not in data.columns[constant_filter.get_support()]]

print(len(constant_columns))
# Out:
# 320

# %%
constant_columns
# Out:
# ['chroma_stft_kew_0',
#  'chroma_stft_min_0',
#  'chroma_stft_max_0',
#  'chroma_stft_std_0',
#  'chroma_stft_mean_0',
#  'chroma_stft_median_0',
#  'chroma_stft_kew_1',
#  'chroma_stft_min_1',
#  'chroma_stft_max_1',
#  'chroma_stft_std_1',
#  'chroma_stft_mean_1',
#  'chroma_stft_median_1',
#  'chroma_stft_kew_2',
#  'chroma_stft_min_2',
#  'chroma_stft_max_2',
#  'chroma_stft_std_2',
#  'chroma_stft_mean_2',
#  'chroma_stft_median_2',
#  'chroma_stft_kew_3',
#  'chroma_stft_min_3',
#  'chroma_stft_max_3',
#  'chroma_stft_std_3',
#  'chroma_stft_mean_3',
#  'chroma_stft_median_3',
#  'chroma_stft_kew_4',
#  'chroma_stft_min_4',
#  'chroma_stft_max_4',
#  'chroma_stft_std_4',
#  'chroma_stft_mean_4',
#  'chroma_stft_median_4',
#  'chroma_stft_kew_5',
#  'chroma_stft_min_5',
#  'chroma_stft_max_5',
#  'chroma_stft_std_5',
#  'chroma_stft_mean_5',
#  'chroma_stft_median_5',
#  'chroma_stft_kew_6',
#  'chroma_stft_min_6',
#  'chroma_stft_max_6',
#  'chroma_stft_std_6',
#  'chroma_stft_mean_6',
#  'chroma_stft_median_6',
#  'chroma_stft_kew_7',
#  'chroma_stft_min_7',
#  'chroma_stft_max_7',
#  'chroma_stft_std_7',
#  'chroma_stft_mean_7',
#  'chroma_stft_median_7',
#  'chroma_stft_kew_8',
#  'chroma_stft_min_8',
#  'chroma_stft_max_8',
#  'chroma_stft_std_8',
#  'chroma_stft_mean_8',
#  'chroma_stft_median_8',
#  'chroma_stft_kew_9',
#  'chroma_stft_min_9',
#  'chroma_stft_max_9',
#  'chroma_stft_std_9',
#  'chroma_stft_mean_9',
#  'chroma_stft_median_9',
#  'chroma_stft_kew_10',
#  'chroma_stft_min_10',
#  'chroma_stft_max_10',
#  'chroma_stft_std_10',
#  'chroma_stft_mean_10',
#  'chroma_stft_median_10',
#  'chroma_stft_kew_11',
#  'chroma_stft_min_11',
#  'chroma_stft_max_11',
#  'chroma_stft_std_11',
#  'chroma_stft_mean_11',
#  'chroma_stft_median_11',
#  'chroma_cqt_kew_0',
#  'chroma_cqt_min_0',
#  'chroma_cqt_max_0',
#  'chroma_cqt_std_0',
#  'chroma_cqt_mean_0',
#  'chroma_cqt_median_0',
#  'chroma_cqt_kew_1',
#  'chroma_cqt_min_1',
#  'chroma_cqt_max_1',
#  'chroma_cqt_std_1',
#  'chroma_cqt_mean_1',
#  'chroma_cqt_median_1',
#  'chroma_cqt_kew_2',
#  'chroma_cqt_min_2',
#  'chroma_cqt_max_2',
#  'chroma_cqt_std_2',
#  'chroma_cqt_mean_2',
#  'chroma_cqt_median_2',
#  'chroma_cqt_kew_3',
#  'chroma_cqt_min_3',
#  'chroma_cqt_max_3',
#  'chroma_cqt_std_3',
#  'chroma_cqt_mean_3',
#  'chroma_cqt_median_3',
#  'chroma_cqt_kew_4',
#  'chroma_cqt_min_4',
#  'chroma_cqt_max_4',
#  'chroma_cqt_std_4',
#  'chroma_cqt_mean_4',
#  'chroma_cqt_median_4',
#  'chroma_cqt_kew_5',
#  'chroma_cqt_min_5',
#  'chroma_cqt_max_5',
#  'chroma_cqt_std_5',
#  'chroma_cqt_mean_5',
#  'chroma_cqt_median_5',
#  'chroma_cqt_kew_6',
#  'chroma_cqt_min_6',
#  'chroma_cqt_max_6',
#  'chroma_cqt_std_6',
#  'chroma_cqt_mean_6',
#  'chroma_cqt_median_6',
#  'chroma_cqt_kew_7',
#  'chroma_cqt_min_7',
#  'chroma_cqt_max_7',
#  'chroma_cqt_std_7',
#  'chroma_cqt_mean_7',
#  'chroma_cqt_median_7',
#  'chroma_cqt_kew_8',
#  'chroma_cqt_min_8',
#  'chroma_cqt_max_8',
#  'chroma_cqt_std_8',
#  'chroma_cqt_mean_8',
#  'chroma_cqt_median_8',
#  'chroma_cqt_kew_9',
#  'chroma_cqt_min_9',
#  'chroma_cqt_max_9',
#  'chroma_cqt_std_9',
#  'chroma_cqt_mean_9',
#  'chroma_cqt_median_9',
#  'chroma_cqt_kew_10',
#  'chroma_cqt_min_10',
#  'chroma_cqt_max_10',
#  'chroma_cqt_std_10',
#  'chroma_cqt_mean_10',
#  'chroma_cqt_median_10',
#  'chroma_cqt_kew_11',
#  'chroma_cqt_min_11',
#  'chroma_cqt_max_11',
#  'chroma_cqt_std_11',
#  'chroma_cqt_mean_11',
#  'chroma_cqt_median_11',
#  'chroma_cens_kew_0',
#  'chroma_cens_min_0',
#  'chroma_cens_max_0',
#  'chroma_cens_std_0',
#  'chroma_cens_mean_0',
#  'chroma_cens_median_0',
#  'chroma_cens_kew_1',
#  'chroma_cens_min_1',
#  'chroma_cens_max_1',
#  'chroma_cens_std_1',
#  'chroma_cens_mean_1',
#  'chroma_cens_median_1',
#  'chroma_cens_kew_2',
#  'chroma_cens_min_2',
#  'chroma_cens_max_2',
#  'chroma_cens_std_2',
#  'chroma_cens_mean_2',
#  'chroma_cens_median_2',
#  'chroma_cens_kew_3',
#  'chroma_cens_min_3',
#  'chroma_cens_max_3',
#  'chroma_cens_std_3',
#  'chroma_cens_mean_3',
#  'chroma_cens_median_3',
#  'chroma_cens_kew_4',
#  'chroma_cens_min_4',
#  'chroma_cens_max_4',
#  'chroma_cens_std_4',
#  'chroma_cens_mean_4',
#  'chroma_cens_median_4',
#  'chroma_cens_kew_5',
#  'chroma_cens_min_5',
#  'chroma_cens_max_5',
#  'chroma_cens_std_5',
#  'chroma_cens_mean_5',
#  'chroma_cens_median_5',
#  'chroma_cens_kew_6',
#  'chroma_cens_min_6',
#  'chroma_cens_max_6',
#  'chroma_cens_std_6',
#  'chroma_cens_mean_6',
#  'chroma_cens_median_6',
#  'chroma_cens_kew_7',
#  'chroma_cens_min_7',
#  'chroma_cens_max_7',
#  'chroma_cens_std_7',
#  'chroma_cens_mean_7',
#  'chroma_cens_median_7',
#  'chroma_cens_kew_8',
#  'chroma_cens_min_8',
#  'chroma_cens_max_8',
#  'chroma_cens_std_8',
#  'chroma_cens_mean_8',
#  'chroma_cens_median_8',
#  'chroma_cens_kew_9',
#  'chroma_cens_min_9',
#  'chroma_cens_max_9',
#  'chroma_cens_std_9',
#  'chroma_cens_mean_9',
#  'chroma_cens_median_9',
#  'chroma_cens_kew_10',
#  'chroma_cens_min_10',
#  'chroma_cens_max_10',
#  'chroma_cens_std_10',
#  'chroma_cens_mean_10',
#  'chroma_cens_median_10',
#  'chroma_cens_kew_11',
#  'chroma_cens_min_11',
#  'chroma_cens_max_11',
#  'chroma_cens_std_11',
#  'chroma_cens_mean_11',
#  'chroma_cens_median_11',
#  'mfcc_kew_0',
#  'mfcc_kew_1',
#  'mfcc_kew_2',
#  'mfcc_kew_3',
#  'mfcc_kurtosis_3',
#  'mfcc_kew_4',
#  'mfcc_kurtosis_4',
#  'mfcc_kew_5',
#  'mfcc_kurtosis_5',
#  'mfcc_kew_6',
#  'mfcc_kurtosis_6',
#  'mfcc_kew_7',
#  'mfcc_kurtosis_7',
#  'mfcc_kew_8',
#  'mfcc_kurtosis_8',
#  'mfcc_kew_9',
#  'mfcc_kurtosis_9',
#  'mfcc_kew_10',
#  'mfcc_kurtosis_10',
#  'mfcc_kew_11',
#  'mfcc_kurtosis_11',
#  'mfcc_kew_12',
#  'mfcc_kurtosis_12',
#  'mfcc_kew_13',
#  'mfcc_kurtosis_13',
#  'mfcc_kew_14',
#  'mfcc_kurtosis_14',
#  'mfcc_kew_15',
#  'mfcc_kurtosis_15',
#  'mfcc_kew_16',
#  'mfcc_kurtosis_16',
#  'mfcc_kew_17',
#  'mfcc_kurtosis_17',
#  'mfcc_kew_18',
#  'mfcc_kurtosis_18',
#  'mfcc_kew_19',
#  'mfcc_kurtosis_19',
#  'rms_kew_0',
#  'rms_min_0',
#  'rms_max_0',
#  'rms_std_0',
#  'rms_mean_0',
#  'rms_median_0',
#  'spectral_centroid_kew_0',
#  'spectral_bandwidth_kew_0',
#  'spectral_contrast_kew_0',
#  'spectral_contrast_std_0',
#  'spectral_contrast_kew_1',
#  'spectral_contrast_std_1',
#  'spectral_contrast_kurtosis_1',
#  'spectral_contrast_kew_2',
#  'spectral_contrast_std_2',
#  'spectral_contrast_kurtosis_2',
#  'spectral_contrast_kew_3',
#  'spectral_contrast_std_3',
#  'spectral_contrast_kurtosis_3',
#  'spectral_contrast_kew_4',
#  'spectral_contrast_std_4',
#  'spectral_contrast_kurtosis_4',
#  'spectral_contrast_kew_5',
#  'spectral_contrast_std_5',
#  'spectral_rolloff_kew_0',
#  'tonnetz_kew_0',
#  'tonnetz_min_0',
#  'tonnetz_max_0',
#  'tonnetz_std_0',
#  'tonnetz_mean_0',
#  'tonnetz_median_0',
#  'tonnetz_kew_1',
#  'tonnetz_min_1',
#  'tonnetz_max_1',
#  'tonnetz_std_1',
#  'tonnetz_mean_1',
#  'tonnetz_median_1',
#  'tonnetz_kew_2',
#  'tonnetz_min_2',
#  'tonnetz_max_2',
#  'tonnetz_std_2',
#  'tonnetz_mean_2',
#  'tonnetz_median_2',
#  'tonnetz_kew_3',
#  'tonnetz_min_3',
#  'tonnetz_max_3',
#  'tonnetz_std_3',
#  'tonnetz_mean_3',
#  'tonnetz_median_3',
#  'tonnetz_kew_4',
#  'tonnetz_min_4',
#  'tonnetz_max_4',
#  'tonnetz_std_4',
#  'tonnetz_mean_4',
#  'tonnetz_median_4',
#  'tonnetz_kew_5',
#  'tonnetz_min_5',
#  'tonnetz_max_5',
#  'tonnetz_std_5',
#  'tonnetz_mean_5',
#  'tonnetz_median_5',
#  'zero_crossing_rate_kew_0',
#  'zero_crossing_rate_min_0',
#  'zero_crossing_rate_max_0',
#  'zero_crossing_rate_std_0',
#  'zero_crossing_rate_mean_0',
#  'zero_crossing_rate_median_0']

# %%
data = constant_filter.transform(data)

# %%
data.shape
# Out:
# (792, 198)

# %%
df = pd.DataFrame(data, label)
df
# Out:
#             0         1         2         3         4         5         6    \
# Label
# 1     -0.920438 -0.274114 -0.288602 -1.193596 -0.024066 -1.266645 -0.083848
# 1      0.136358 -1.481371  0.517289  1.347993 -0.115323  2.365486  0.637198
# 1      0.718688  2.729941  0.539202  3.406664  1.738767  0.945224  2.564557
# 1      0.231711 -0.764905 -0.171808 -1.244604  0.048819  1.684652  2.159814
# 1     -1.433215 -0.083812 -0.129989 -0.817375 -0.144148 -0.874035  0.279901
# ...         ...       ...       ...       ...       ...       ...       ...
# 0     -1.332615 -1.220260 -0.399320 -0.858080 -0.937122 -1.112958 -0.459458
# 0     -1.401194  1.033810 -0.622381  1.776094 -0.923331  0.616756  1.026678
# 0     -0.895876  0.282211 -0.544669 -1.268309 -0.699188 -0.872076 -0.986965
# 0     -1.182581 -1.069113 -0.512044 -0.711488 -0.935645 -1.379811 -1.406859
# 0      2.011852  1.665242 -0.349201  2.002676  0.358680  3.289263  0.303397
#
#             7         8         9    ...          188          189       190  \
# Label                                ...
# 1     -1.082290 -0.932199 -0.028455  ...  4992.503144  4920.336914 -0.374785
# 1      1.723358 -0.433868 -0.010923  ...  4483.606222  4220.507812  4.208054
# 1     -1.387718  1.883393  0.337301  ...  3647.294612  3192.297363 -0.678697
# 1      0.469628 -1.120641  0.548145  ...  7308.172475  7983.435059  0.597110
# 1     -0.283576 -1.285667  0.210506  ...  5903.980966  5840.881348 -0.030101
# ...         ...       ...       ...  ...          ...          ...       ...
# 0     -0.268156 -1.127672 -0.760497  ...  6971.757843  7251.306152  0.513016
# 0     -0.321422  0.773214  0.180635  ...  6460.210936  6718.359375 -1.239889
# 0     -1.351679 -1.046322 -1.018566  ...  5085.469249  4936.486816 -0.484211
# 0     -1.255797 -1.201236 -1.092943  ...  3591.861614  3509.912109  0.682838
# 0     -1.284021 -0.140826 -1.701649  ...  3263.146935  2745.483398  1.935607
#
#             191       192       193       194       195       196       197
# Label
# 1      0.891238 -1.030463 -0.192172  0.384000 -0.415851 -0.539747  3.242503
# 1      1.117581  1.105892  0.077508  0.209567  0.366745  0.115312 -0.313862
# 1      0.573413  0.063356 -0.684246  0.154728 -0.058632  0.486480 -0.147254
# 1      0.014670  0.694812  1.412927  0.425779  0.770083  0.467516 -0.347516
# 1     -0.280648  0.296000 -0.779434  0.924981  0.940209 -0.384372  7.626171
# ...         ...       ...       ...       ...       ...       ...       ...
# 0      0.200870  0.211364  0.323342  2.472084 -0.010748  0.813091  2.920797
# 0     -0.051348  0.891065 -0.326609  0.378586  2.335101  0.258094  3.043618
# 0     -0.238451  2.233149  0.874422  1.107583  1.169321  0.248444  0.049509
# 0      1.518193  1.842552  2.092778  0.407291  0.826455  0.905429  0.431357
# 0     -0.403419 -0.314280 -1.295047  0.298287  3.377060 -0.546842  0.649744
#
# [792 rows x 198 columns]

# %% [markdown]
# ## **Scale the data**

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(data)
# Out:
# StandardScaler()

# %%
scaled_data = scaler.transform(data)
scaled_data
# Out:
# array([[-0.59064096, -0.29371171, -0.19862848, ..., -0.58740734,
#         -0.71419751,  1.69370007],
#        [ 0.07705694, -1.07937212,  0.35176783, ..., -0.16680047,
#         -0.30780743, -0.59091472],
#        [ 0.44498026,  1.6612717 ,  0.36673371, ..., -0.39541968,
#         -0.0775389 , -0.4838852 ],
#        ...,
#        [-0.57512201,  0.06833454, -0.37351296, ...,  0.26454457,
#         -0.22521364, -0.35748458],
#        [-0.75626582, -0.81108245, -0.35123149, ...,  0.08027105,
#          0.18237145, -0.11218433],
#        [ 1.26201845,  0.96838545, -0.24001526, ...,  1.45109481,
#         -0.71859942,  0.0281076 ]])

# %%
scaled_data.shape
# Out:
# (792, 198)

# %% [markdown]
# ## **Decision Tree Model**

# %%
from sklearn.model_selection import train_test_split

X_train, X_Validation, Y_train, Y_Validation= train_test_split(scaled_data, label, test_size= 0.2)

# %%
from sklearn.tree import DecisionTreeClassifier

# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,Y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_Validation)

# %%
# Calculate the mean absolute error for the model
from sklearn.metrics import mean_absolute_error

DT_Validation_MSE = mean_absolute_error(y_pred, Y_Validation)
print(f'Mean Square Error for Decision Tree Model is: {DT_Validation_MSE}')
# Out:
# Mean Square Error for Decision Tree Model is: 0.4716981132075472

# %% [markdown]
# ## So, the accuracy is approximately 53 %

# %% [markdown]
# # **Hypertunning th the data**

# %%
pwd = os.getcwd()
data_path = os.path.join(pwd,'/content/Final_Data.csv')
data2 = pd.read_csv(data_path)
data2.head()
# Out:
#            Artist                           Title  Label  \
# 0      The Weeknd                 Blinding Lights      1
# 1  Olivia Rodrigo                        Good 4 U      1
# 2  Olivia Rodrigo                 Drivers License      1
# 3       Lil Nas X  Montero (Call Me By Your Name)      1
# 4             BTS                          Butter      1
#
#                                     song_path  \
# 0                 popular/Blinding Lights.mp3
# 1                        popular/Good 4 U.mp3
# 2                 popular/Drivers License.mp3
# 3  popular/Montero (Call Me By Your Name).mp3
# 4                          popular/Butter.mp3
#
#                                        new_song_path  \
# 0  /content/drive/MyDrive/bill/popular/Blinding L...
# 1   /content/drive/MyDrive/bill/popular/Good 4 U.mp3
# 2  /content/drive/MyDrive/bill/popular/Drivers Li...
# 3  /content/drive/MyDrive/bill/popular/Montero (C...
# 4     /content/drive/MyDrive/bill/popular/Butter.mp3
#
#                                extracted_chorus_path  chroma_stft_kew_0  \
# 0                 chorus_extract/Blinding Lights.wav           0.476192
# 1                        chorus_extract/Good 4 U.wav           1.048281
# 2                 chorus_extract/Drivers License.wav           1.391406
# 3  chorus_extract/Montero (Call Me By Your Name).wav           0.898662
# 4                          chorus_extract/Butter.wav           0.299845
#
#    chroma_stft_min_0  chroma_stft_max_0  chroma_stft_std_0  ...  \
# 0           0.016697                1.0           0.290165  ...
# 1           0.006909                1.0           0.274690  ...
# 2           0.000700                1.0           0.307762  ...
# 3           0.002983                1.0           0.239849  ...
# 4           0.036609                1.0           0.334760  ...
#
#    tonnetz_mean_5  tonnetz_median_5  tonnetz_kurtosis_5  \
# 0        0.007436          0.000934           -0.539747
# 1       -0.010380         -0.011803            0.115312
# 2       -0.002966         -0.011493            0.486480
# 3       -0.013886         -0.021088            0.467516
# 4        0.006860          0.004859           -0.384372
#
#    zero_crossing_rate_kew_0  zero_crossing_rate_min_0  \
# 0                  1.466814                  0.037551
# 1                 -0.398137                  0.054286
# 2                  0.746785                  0.022630
# 3                  0.528719                  0.048934
# 4                  2.536822                  0.040181
#
#    zero_crossing_rate_max_0  zero_crossing_rate_std_0  \
# 0                  0.159229                  0.020931
# 1                  0.224626                  0.035255
# 2                  0.176054                  0.031968
# 3                  0.266757                  0.043461
# 4                  0.221769                  0.027223
#
#    zero_crossing_rate_mean_0  zero_crossing_rate_median_0  \
# 0                   0.082646                     0.079751
# 1                   0.147474                     0.157392
# 2                   0.076661                     0.065692
# 3                   0.143693                     0.137687
# 4                   0.095766                     0.090703
#
#    zero_crossing_rate_kurtosis_0
# 0                       3.242503
# 1                      -0.313862
# 2                      -0.147254
# 3                      -0.347516
# 4                       7.626171
#
# [5 rows x 524 columns]

# %%
label2 = data2['Label']

data2 = data2.drop(['Artist',	'Title', 'song_path',	'new_song_path',	'extracted_chorus_path', 'Label'], axis=1)

# %%
cor_matrix = data2.corr().abs()
print(cor_matrix)
# Out:
#                                chroma_stft_kew_0  chroma_stft_min_0  \
# chroma_stft_kew_0                       1.000000           0.371227
# chroma_stft_min_0                       0.371227           1.000000
# chroma_stft_max_0                       0.007775           0.017458
# chroma_stft_std_0                       0.608770           0.081623
# chroma_stft_mean_0                      0.957253           0.495092
# ...                                          ...                ...
# zero_crossing_rate_max_0                0.079045           0.261665
# zero_crossing_rate_std_0                0.045875           0.274687
# zero_crossing_rate_mean_0               0.227831           0.151675
# zero_crossing_rate_median_0             0.243171           0.129835
# zero_crossing_rate_kurtosis_0           0.023809           0.023571
#
#                                chroma_stft_max_0  chroma_stft_std_0  \
# chroma_stft_kew_0                       0.007775           0.608770
# chroma_stft_min_0                       0.017458           0.081623
# chroma_stft_max_0                       1.000000           0.107553
# chroma_stft_std_0                       0.107553           1.000000
# chroma_stft_mean_0                      0.051734           0.562567
# ...                                          ...                ...
# zero_crossing_rate_max_0                0.098095           0.026015
# zero_crossing_rate_std_0                0.084236           0.125326
# zero_crossing_rate_mean_0               0.088060           0.114608
# zero_crossing_rate_median_0             0.084824           0.129071
# zero_crossing_rate_kurtosis_0           0.053854           0.029232
#
#                                chroma_stft_mean_0  chroma_stft_median_0  \
# chroma_stft_kew_0                        0.957253              0.917040
# chroma_stft_min_0                        0.495092              0.517531
# chroma_stft_max_0                        0.051734              0.028075
# chroma_stft_std_0                        0.562567              0.373904
# chroma_stft_mean_0                       1.000000              0.961666
# ...                                           ...                   ...
# zero_crossing_rate_max_0                 0.113519              0.129376
# zero_crossing_rate_std_0                 0.001702              0.019065
# zero_crossing_rate_mean_0                0.231609              0.235994
# zero_crossing_rate_median_0              0.241948              0.245211
# zero_crossing_rate_kurtosis_0            0.031767              0.035196
#
#                                chroma_stft_kurtosis_0  chroma_stft_kew_1  \
# chroma_stft_kew_0                            0.872730           0.529103
# chroma_stft_min_0                            0.227529           0.333706
# chroma_stft_max_0                            0.022703           0.030939
# chroma_stft_std_0                            0.753498           0.014716
# chroma_stft_mean_0                           0.782494           0.516246
# ...                                               ...                ...
# zero_crossing_rate_max_0                     0.013385           0.043337
# zero_crossing_rate_std_0                     0.069643           0.052896
# zero_crossing_rate_mean_0                    0.134317           0.171409
# zero_crossing_rate_median_0                  0.149730           0.184343
# zero_crossing_rate_kurtosis_0                0.009960           0.041947
#
#                                chroma_stft_min_1  chroma_stft_max_1  ...  \
# chroma_stft_kew_0                       0.308363           0.094832  ...
# chroma_stft_min_0                       0.809903           0.010094  ...
# chroma_stft_max_0                       0.025659           0.005727  ...
# chroma_stft_std_0                       0.129644           0.065915  ...
# chroma_stft_mean_0                      0.415525           0.076424  ...
# ...                                          ...                ...  ...
# zero_crossing_rate_max_0                0.247923           0.098008  ...
# zero_crossing_rate_std_0                0.285485           0.054041  ...
# zero_crossing_rate_mean_0               0.139273           0.080144  ...
# zero_crossing_rate_median_0             0.119664           0.065941  ...
# zero_crossing_rate_kurtosis_0           0.059902           0.054957  ...
#
#                                tonnetz_mean_5  tonnetz_median_5  \
# chroma_stft_kew_0                    0.090566          0.107142
# chroma_stft_min_0                    0.058051          0.045058
# chroma_stft_max_0                    0.004854          0.007240
# chroma_stft_std_0                    0.002471          0.008467
# chroma_stft_mean_0                   0.109993          0.117800
# ...                                       ...               ...
# zero_crossing_rate_max_0             0.012176          0.031299
# zero_crossing_rate_std_0             0.038456          0.054123
# zero_crossing_rate_mean_0            0.051424          0.005432
# zero_crossing_rate_median_0          0.056891          0.001487
# zero_crossing_rate_kurtosis_0        0.047813          0.045349
#
#                                tonnetz_kurtosis_5  zero_crossing_rate_kew_0  \
# chroma_stft_kew_0                        0.089319                  0.190798
# chroma_stft_min_0                        0.135096                  0.060600
# chroma_stft_max_0                        0.011509                  0.065172
# chroma_stft_std_0                        0.113215                  0.158057
# chroma_stft_mean_0                       0.044578                  0.160414
# ...                                           ...                       ...
# zero_crossing_rate_max_0                 0.081149                  0.189289
# zero_crossing_rate_std_0                 0.113560                  0.370523
# zero_crossing_rate_mean_0                0.023593                  0.363811
# zero_crossing_rate_median_0              0.033873                  0.448134
# zero_crossing_rate_kurtosis_0            0.009882                  0.217352
#
#                                zero_crossing_rate_min_0  \
# chroma_stft_kew_0                              0.227738
# chroma_stft_min_0                              0.023586
# chroma_stft_max_0                              0.028385
# chroma_stft_std_0                              0.173494
# chroma_stft_mean_0                             0.209077
# ...                                                 ...
# zero_crossing_rate_max_0                       0.491480
# zero_crossing_rate_std_0                       0.068530
# zero_crossing_rate_mean_0                      0.831051
# zero_crossing_rate_median_0                    0.832737
# zero_crossing_rate_kurtosis_0                  0.130876
#
#                                zero_crossing_rate_max_0  \
# chroma_stft_kew_0                              0.079045
# chroma_stft_min_0                              0.261665
# chroma_stft_max_0                              0.098095
# chroma_stft_std_0                              0.026015
# chroma_stft_mean_0                             0.113519
# ...                                                 ...
# zero_crossing_rate_max_0                       1.000000
# zero_crossing_rate_std_0                       0.775541
# zero_crossing_rate_mean_0                      0.756880
# zero_crossing_rate_median_0                    0.679963
# zero_crossing_rate_kurtosis_0                  0.201501
#
#                                zero_crossing_rate_std_0  \
# chroma_stft_kew_0                              0.045875
# chroma_stft_min_0                              0.274687
# chroma_stft_max_0                              0.084236
# chroma_stft_std_0                              0.125326
# chroma_stft_mean_0                             0.001702
# ...                                                 ...
# zero_crossing_rate_max_0                       0.775541
# zero_crossing_rate_std_0                       1.000000
# zero_crossing_rate_mean_0                      0.286494
# zero_crossing_rate_median_0                    0.196729
# zero_crossing_rate_kurtosis_0                  0.072649
#
#                                zero_crossing_rate_mean_0  \
# chroma_stft_kew_0                               0.227831
# chroma_stft_min_0                               0.151675
# chroma_stft_max_0                               0.088060
# chroma_stft_std_0                               0.114608
# chroma_stft_mean_0                              0.231609
# ...                                                  ...
# zero_crossing_rate_max_0                        0.756880
# zero_crossing_rate_std_0                        0.286494
# zero_crossing_rate_mean_0                       1.000000
# zero_crossing_rate_median_0                     0.989216
# zero_crossing_rate_kurtosis_0                   0.097521
#
#                                zero_crossing_rate_median_0  \
# chroma_stft_kew_0                                 0.243171
# chroma_stft_min_0                                 0.129835
# chroma_stft_max_0                                 0.084824
# chroma_stft_std_0                                 0.129071
# chroma_stft_mean_0                                0.241948
# ...                                                    ...
# zero_crossing_rate_max_0                          0.679963
# zero_crossing_rate_std_0                          0.196729
# zero_crossing_rate_mean_0                         0.989216
# zero_crossing_rate_median_0                       1.000000
# zero_crossing_rate_kurtosis_0                     0.072073
#
#                                zero_crossing_rate_kurtosis_0
# chroma_stft_kew_0                                   0.023809
# chroma_stft_min_0                                   0.023571
# chroma_stft_max_0                                   0.053854
# chroma_stft_std_0                                   0.029232
# chroma_stft_mean_0                                  0.031767
# ...                                                      ...
# zero_crossing_rate_max_0                            0.201501
# zero_crossing_rate_std_0                            0.072649
# zero_crossing_rate_mean_0                           0.097521
# zero_crossing_rate_median_0                         0.072073
# zero_crossing_rate_kurtosis_0                       1.000000
#
# [518 rows x 518 columns]

# %%
from sklearn.feature_selection import VarianceThreshold

constant_filter2 = VarianceThreshold(threshold=0.6)
constant_filter2.fit(data2)
# Out:
# VarianceThreshold(threshold=0.6)

# %%
print(f'Length of new data after filtering: {len(data2.columns[constant_filter2.get_support()])}')

constant_columns = [column for column in data2.columns
                    if column not in data2.columns[constant_filter2.get_support()]]

print(f'Length of constant columns: {len(constant_columns)}')
# Out:
# Length of new data after filtering: 209
# Length of constant columns: 309

# %%
data2 = constant_filter2.transform(data2)
data2.shape
# Out:
# (792, 209)

# %%
from sklearn.preprocessing import StandardScaler

scaler2 = StandardScaler()
scaler2.fit(data2)

scaled_data2 = scaler2.transform(data2)
scaled_data2
# Out:
# array([[-0.59064096, -0.29371171, -0.19862848, ..., -0.58740734,
#         -0.71419751,  1.69370007],
#        [ 0.07705694, -1.07937212,  0.35176783, ..., -0.16680047,
#         -0.30780743, -0.59091472],
#        [ 0.44498026,  1.6612717 ,  0.36673371, ..., -0.39541968,
#         -0.0775389 , -0.4838852 ],
#        ...,
#        [-0.57512201,  0.06833454, -0.37351296, ...,  0.26454457,
#         -0.22521364, -0.35748458],
#        [-0.75626582, -0.81108245, -0.35123149, ...,  0.08027105,
#          0.18237145, -0.11218433],
#        [ 1.26201845,  0.96838545, -0.24001526, ...,  1.45109481,
#         -0.71859942,  0.0281076 ]])

# %%
from sklearn.model_selection import train_test_split

X_train2, X_Validation2, Y_train2, Y_Validation2= train_test_split(scaled_data2, label2, test_size= 0.2)

# %%
from sklearn.tree import DecisionTreeClassifier

# Create Decision Tree classifer object
clf2 = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf2 = clf.fit(X_train2,Y_train2)

#Predict the response for test dataset
y_pred2 = clf2.predict(X_Validation2)

# %%
# Calculate the mean absolute error for the model
from sklearn.metrics import mean_absolute_error

DT_Validation_MSE2 = mean_absolute_error(y_pred2, Y_Validation2)
print(f'Mean Square Error (2) for Decision Tree Model is: {DT_Validation_MSE2}')
# Out:
# Mean Square Error (2) for Decision Tree Model is: 0.4276729559748428

# %% [markdown]
# ## So, the accuracy is approximately 58 %
