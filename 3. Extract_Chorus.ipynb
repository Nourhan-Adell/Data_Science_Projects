# %% [markdown]
# <a href="https://colab.research.google.com/github/Nourhan-Adell/Data_Science_Projects/blob/main/Billboard_Hit_Songs_Project/Extract_Chorus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Extract 15s chorus**

# %%
pip install pychorus
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pychorus
#   Downloading pychorus-v0.1.tar.gz (5.1 kB)
# Requirement already satisfied: librosa in /usr/local/lib/python3.7/dist-packages (from pychorus) (0.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pychorus) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pychorus) (1.7.3)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.7/dist-packages (from pychorus) (0.10.3.post1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from pychorus) (3.2.2)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa->pychorus) (4.4.2)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa->pychorus) (1.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from librosa->pychorus) (21.3)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa->pychorus) (0.4.0)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa->pychorus) (3.0.0)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.7/dist-packages (from librosa->pychorus) (0.56.2)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from librosa->pychorus) (1.0.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.7/dist-packages (from librosa->pychorus) (1.1.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa->pychorus) (4.12.0)
# Requirement already satisfied: setuptools<60 in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa->pychorus) (57.4.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa->pychorus) (0.39.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->librosa->pychorus) (3.0.9)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa->pychorus) (2.23.0)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa->pychorus) (1.4.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa->pychorus) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa->pychorus) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa->pychorus) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa->pychorus) (2022.6.15)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa->pychorus) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile->pychorus) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile->pychorus) (2.21)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba>=0.43.0->librosa->pychorus) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba>=0.43.0->librosa->pychorus) (3.8.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->pychorus) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->pychorus) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->pychorus) (1.4.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->matplotlib->pychorus) (1.15.0)
# Building wheels for collected packages: pychorus
#   Building wheel for pychorus (setup.py) ... done
#   Created wheel for pychorus: filename=pychorus-0.1-py3-none-any.whl size=6472 sha256=484f5088312c19c7f7482cc5f09a077140ab905ce089023efe836a07f17c445e
#   Stored in directory: /root/.cache/pip/wheels/50/b8/df/82626ca98c4d1443c1e5a93922e8194063af3c317b4e8444bd
# Successfully built pychorus
# Installing collected packages: pychorus
# Successfully installed pychorus-0.1

# %%
# import necessary libraries 
import os 
import pandas as pd
import warnings 
warnings.filterwarnings(action='ignore')

# %%
# read new data table with downloaded full songs path
pwd = os.getcwd()
data_path = os.path.join(pwd,'Billboard_Data_fullsongs.csv')
data = pd.read_csv(data_path)
df = data.copy()

# %%
pwd
# Out:
# '/content'

# %%
df[df['song_path'].isna()] #check for null paths
# Out:
#                 Artist    Title  Label song_path
# 152  Justin Timberlake  Mirrors      1       NaN

# %%
df = df.dropna()

# %%
df[df['song_path'].isna()] #check for null paths
# Out:
# Empty DataFrame
# Columns: [Artist, Title, Label, song_path]
# Index: []

# %%
full_songs_path = list(df['song_path']) # list of full songs downloaded path 
chorus_extract_path = '/content/Untitled Folder' # path to save extracted chorus
extracted_songs = [basename.replace('.wav','') for basename in os.listdir(chorus_extract_path)] # basename/ song name of already extracted song to avoid repitition in chorus extraction 
extracted_songs
# Out:
# []

# %%
from pychorus import find_and_output_chorus # import chorus ectractor lib
not_extrated = [] # list to track not extracted choruses

# %%
# helper function to extract 15s choruses from songs as required in paper 
def extract_chorus(path_list, output_path):
    for path in path_list:
        basename = os.path.basename(str(path)).replace('.mp3', '')
        save_path = f'{output_path}/{basename}.wav' # output path as .wav extension 
        if basename in extracted_songs:
            print('song already exists')
        else:
            chorus = find_and_output_chorus(str(path), str(save_path), 15)
            if chorus == None:
                not_extrated.append(basename)

# %%
extract_chorus(full_songs_path,chorus_extract_path) #extract all choruses
# Out:
# Best chorus found at 2 min 42.54 sec
# Best chorus found at 2 min 40.81 sec
# Best chorus found at 3 min 22.06 sec
# Best chorus found at 2 min 11.99 sec
# Best chorus found at 2 min 17.09 sec
# Best chorus found at 2 min 14.07 sec
# Best chorus found at 3 min 24.57 sec
# Best chorus found at 2 min 59.90 sec
# Best chorus found at 1 min 26.87 sec
# Best chorus found at 1 min 21.68 sec
# Best chorus found at 1 min 59.04 sec
# Best chorus found at 2 min 57.88 sec
# Best chorus found at 1 min 36.00 sec
# Best chorus found at 3 min 6.78 sec
# Best chorus found at 3 min 1.93 sec
# Best chorus found at 2 min 37.64 sec
# Best chorus found at 3 min 38.64 sec
# Best chorus found at 1 min 39.55 sec
# Best chorus found at 1 min 17.43 sec
# Best chorus found at 3 min 36.22 sec
# Best chorus found at 1 min 13.13 sec
# Best chorus found at 1 min 32.47 sec
# Best chorus found at 2 min 14.05 sec
# Best chorus found at 1 min 41.02 sec
# Best chorus found at 3 min 3.61 sec
# Best chorus found at 2 min 8.47 sec
# Best chorus found at 3 min 19.78 sec
# Best chorus found at 1 min 0.90 sec
# Best chorus found at 1 min 42.68 sec
# Best chorus found at 2 min 32.76 sec
# Best chorus found at 4 min 24.15 sec
# Best chorus found at 2 min 35.73 sec
# Best chorus found at 2 min 33.69 sec
# Best chorus found at 3 min 5.35 sec
# Best chorus found at 0 min 45.87 sec
# Best chorus found at 2 min 46.37 sec
# Best chorus found at 2 min 1.78 sec
# Best chorus found at 3 min 5.09 sec
# Best chorus found at 2 min 20.80 sec
# Best chorus found at 1 min 26.33 sec
# Best chorus found at 2 min 33.92 sec
# Best chorus found at 1 min 42.49 sec
# Best chorus found at 2 min 52.49 sec
# Best chorus found at 2 min 13.64 sec
# Best chorus found at 2 min 19.61 sec
# Best chorus found at 2 min 11.81 sec
# Best chorus found at 2 min 43.77 sec
# Best chorus found at 2 min 15.54 sec
# Best chorus found at 2 min 7.92 sec
# Best chorus found at 2 min 51.34 sec
# Best chorus found at 2 min 4.03 sec
# Best chorus found at 1 min 23.78 sec
# Best chorus found at 1 min 30.43 sec
# Best chorus found at 1 min 51.02 sec
# Best chorus found at 3 min 4.23 sec
# Best chorus found at 3 min 14.56 sec
# Best chorus found at 2 min 44.21 sec
# Best chorus found at 1 min 25.44 sec
# Best chorus found at 2 min 46.56 sec
# Best chorus found at 2 min 52.85 sec
# Best chorus found at 3 min 27.77 sec
# Best chorus found at 3 min 29.04 sec
# Best chorus found at 7 min 35.68 sec
# Best chorus found at 3 min 52.65 sec
# Best chorus found at 2 min 19.44 sec
# Best chorus found at 3 min 22.44 sec
# Best chorus found at 2 min 50.78 sec
# Best chorus found at 1 min 35.59 sec
# Best chorus found at 3 min 17.74 sec
# Best chorus found at 3 min 2.21 sec
# Best chorus found at 2 min 56.94 sec
# Best chorus found at 2 min 37.42 sec
# Best chorus found at 4 min 21.78 sec
# Best chorus found at 1 min 45.25 sec
# Best chorus found at 1 min 59.44 sec
# Best chorus found at 2 min 22.78 sec
# Best chorus found at 2 min 56.93 sec
# Best chorus found at 2 min 27.35 sec
# Best chorus found at 3 min 18.44 sec
# Best chorus found at 2 min 41.03 sec
# Best chorus found at 4 min 22.44 sec
# Best chorus found at 1 min 37.62 sec
# Best chorus found at 0 min 43.06 sec
# Best chorus found at 1 min 45.46 sec
# Best chorus found at 2 min 58.84 sec
# Best chorus found at 2 min 58.61 sec
# Best chorus found at 3 min 6.12 sec
# Best chorus found at 3 min 9.47 sec
# Best chorus found at 1 min 36.77 sec
# Best chorus found at 2 min 41.39 sec
# Best chorus found at 3 min 3.41 sec
# Best chorus found at 3 min 49.89 sec
# Best chorus found at 4 min 23.18 sec
# Best chorus found at 3 min 10.36 sec
# Best chorus found at 2 min 29.72 sec
# Best chorus found at 4 min 26.27 sec
# Best chorus found at 2 min 43.46 sec
# Best chorus found at 3 min 28.18 sec
# Best chorus found at 3 min 3.95 sec
# Best chorus found at 1 min 55.09 sec
# Best chorus found at 1 min 33.24 sec
# No choruses were detected. Try a smaller search duration
# Best chorus found at 2 min 52.68 sec
# Best chorus found at 2 min 43.38 sec
# Best chorus found at 2 min 2.93 sec
# Best chorus found at 5 min 31.74 sec
# Best chorus found at 1 min 15.75 sec
# Best chorus found at 2 min 53.27 sec
# Best chorus found at 3 min 10.55 sec
# Best chorus found at 3 min 33.43 sec
# Best chorus found at 3 min 17.53 sec
# Best chorus found at 1 min 58.29 sec
# Best chorus found at 2 min 11.12 sec
# Best chorus found at 2 min 41.58 sec
# Best chorus found at 3 min 33.39 sec
# Best chorus found at 2 min 26.92 sec
# Best chorus found at 3 min 34.65 sec
# Best chorus found at 3 min 37.07 sec
# Best chorus found at 3 min 0.55 sec
# Best chorus found at 3 min 15.86 sec
# Best chorus found at 3 min 2.32 sec
# Best chorus found at 4 min 44.19 sec
# Best chorus found at 1 min 53.48 sec
# Best chorus found at 2 min 47.73 sec
# Best chorus found at 2 min 9.47 sec
# Best chorus found at 1 min 36.00 sec
# Best chorus found at 3 min 17.04 sec
# Best chorus found at 3 min 28.75 sec
# Best chorus found at 2 min 47.32 sec
# Best chorus found at 3 min 34.40 sec
# Best chorus found at 3 min 39.28 sec
# Best chorus found at 3 min 48.98 sec
# Best chorus found at 2 min 19.41 sec
# Best chorus found at 2 min 20.97 sec
# Best chorus found at 1 min 41.16 sec
# Best chorus found at 2 min 29.68 sec
# Best chorus found at 3 min 12.05 sec
# Best chorus found at 2 min 9.95 sec
# Best chorus found at 1 min 51.60 sec
# Best chorus found at 2 min 36.15 sec
# Best chorus found at 2 min 31.73 sec
# Best chorus found at 2 min 12.73 sec
# Best chorus found at 1 min 31.35 sec
# Best chorus found at 3 min 3.25 sec
# Best chorus found at 1 min 50.82 sec
# Best chorus found at 3 min 38.18 sec
# Best chorus found at 3 min 17.26 sec
# Best chorus found at 2 min 49.49 sec
# Best chorus found at 2 min 27.10 sec
# Best chorus found at 1 min 25.01 sec
# Best chorus found at 2 min 57.67 sec
# Best chorus found at 2 min 48.93 sec
# Best chorus found at 7 min 15.91 sec
# Best chorus found at 1 min 56.94 sec
# Best chorus found at 3 min 8.30 sec
# Best chorus found at 4 min 57.03 sec
# Best chorus found at 3 min 1.81 sec
# Best chorus found at 3 min 40.46 sec
# Best chorus found at 2 min 17.57 sec
# Best chorus found at 4 min 1.63 sec
# Best chorus found at 2 min 51.93 sec
# Best chorus found at 3 min 5.36 sec
# Best chorus found at 3 min 17.19 sec
# Best chorus found at 1 min 14.44 sec
# Best chorus found at 3 min 13.27 sec
# Best chorus found at 3 min 0.70 sec
# Best chorus found at 3 min 49.90 sec
# Best chorus found at 1 min 25.04 sec
# Best chorus found at 2 min 52.10 sec
# Best chorus found at 3 min 55.44 sec
# Best chorus found at 3 min 30.45 sec
# Best chorus found at 3 min 28.33 sec
# Best chorus found at 3 min 30.57 sec
# Best chorus found at 2 min 53.37 sec
# Best chorus found at 2 min 44.83 sec
# Best chorus found at 1 min 39.90 sec
# Best chorus found at 2 min 1.29 sec
# Best chorus found at 1 min 51.96 sec
# Best chorus found at 3 min 29.71 sec
# Best chorus found at 1 min 35.98 sec
# Best chorus found at 3 min 41.57 sec
# Best chorus found at 2 min 32.49 sec
# Best chorus found at 2 min 57.00 sec
# Best chorus found at 3 min 25.06 sec
# Best chorus found at 3 min 26.43 sec
# Best chorus found at 2 min 6.08 sec
# Best chorus found at 3 min 2.97 sec
# Best chorus found at 3 min 0.55 sec
# Best chorus found at 3 min 24.00 sec
# Best chorus found at 3 min 19.61 sec
# Best chorus found at 3 min 5.92 sec
# Best chorus found at 3 min 30.80 sec
# Best chorus found at 2 min 46.94 sec
# Best chorus found at 3 min 4.78 sec
# Best chorus found at 2 min 53.29 sec
# Best chorus found at 2 min 48.02 sec
# Best chorus found at 2 min 9.40 sec
# Best chorus found at 3 min 1.84 sec
# Best chorus found at 7 min 19.87 sec
# Best chorus found at 1 min 25.60 sec
# Best chorus found at 5 min 50.68 sec
# Best chorus found at 3 min 42.44 sec
# Best chorus found at 2 min 44.14 sec
# Best chorus found at 4 min 1.36 sec
# Best chorus found at 3 min 11.37 sec
# Best chorus found at 1 min 20.57 sec
# Best chorus found at 4 min 25.23 sec
# Best chorus found at 3 min 22.07 sec
# Best chorus found at 3 min 44.08 sec
# Best chorus found at 2 min 50.43 sec
# Best chorus found at 2 min 47.48 sec
# Best chorus found at 4 min 3.30 sec
# Best chorus found at 1 min 24.68 sec
# Best chorus found at 3 min 42.91 sec
# Best chorus found at 3 min 8.10 sec
# Best chorus found at 2 min 54.36 sec
# Best chorus found at 3 min 11.43 sec
# Best chorus found at 1 min 5.17 sec
# Best chorus found at 1 min 12.81 sec
# Best chorus found at 2 min 25.23 sec
# Best chorus found at 2 min 10.95 sec
# Best chorus found at 2 min 53.75 sec
# Best chorus found at 2 min 37.88 sec
# Best chorus found at 2 min 0.84 sec
# Best chorus found at 1 min 35.19 sec
# Best chorus found at 3 min 5.44 sec
# Best chorus found at 1 min 14.10 sec
# Best chorus found at 2 min 37.47 sec
# Best chorus found at 2 min 36.33 sec
# Best chorus found at 2 min 27.24 sec
# Best chorus found at 1 min 1.98 sec
# Best chorus found at 3 min 44.33 sec
# Best chorus found at 2 min 28.02 sec
# Best chorus found at 2 min 54.84 sec
# Best chorus found at 2 min 55.34 sec
# Best chorus found at 2 min 42.10 sec
# Best chorus found at 2 min 28.15 sec
# Best chorus found at 3 min 33.52 sec
# Best chorus found at 1 min 12.04 sec
# Best chorus found at 2 min 15.04 sec
# Best chorus found at 2 min 56.18 sec
# No choruses were detected. Try a smaller search duration
# Best chorus found at 2 min 52.54 sec
# No choruses were detected. Try a smaller search duration
# Best chorus found at 2 min 39.74 sec
# Best chorus found at 2 min 45.11 sec
# Best chorus found at 3 min 21.52 sec
# Best chorus found at 2 min 3.14 sec
# Best chorus found at 0 min 43.62 sec
# Best chorus found at 0 min 35.66 sec
# Best chorus found at 4 min 59.24 sec
# Best chorus found at 1 min 36.75 sec
# Best chorus found at 4 min 9.75 sec
# Best chorus found at 2 min 15.38 sec
# Best chorus found at 2 min 35.76 sec
# Best chorus found at 1 min 41.74 sec
# Best chorus found at 2 min 23.94 sec
# Best chorus found at 3 min 21.49 sec
# Best chorus found at 2 min 7.39 sec
# Best chorus found at 2 min 43.60 sec
# Best chorus found at 4 min 4.44 sec
# Best chorus found at 1 min 55.50 sec
# Best chorus found at 3 min 36.20 sec
# Best chorus found at 2 min 28.75 sec
# Best chorus found at 2 min 35.26 sec
# Best chorus found at 1 min 16.71 sec
# Best chorus found at 0 min 56.45 sec
# Best chorus found at 1 min 10.35 sec
# Best chorus found at 1 min 34.15 sec
# Best chorus found at 2 min 9.34 sec
# Best chorus found at 1 min 42.49 sec
# Best chorus found at 2 min 5.65 sec
# No choruses were detected. Try a smaller search duration
# Best chorus found at 2 min 56.96 sec
# Best chorus found at 2 min 20.71 sec
# Best chorus found at 1 min 28.17 sec
# Best chorus found at 1 min 0.90 sec
# Best chorus found at 1 min 18.16 sec
# Best chorus found at 1 min 19.32 sec
# Best chorus found at 3 min 12.42 sec
# Best chorus found at 2 min 23.03 sec
# Best chorus found at 2 min 34.84 sec
# Best chorus found at 3 min 16.16 sec
# Best chorus found at 2 min 47.65 sec
# Best chorus found at 3 min 19.28 sec
# Best chorus found at 2 min 56.01 sec
# Best chorus found at 2 min 12.76 sec
# Best chorus found at 1 min 53.58 sec
# Best chorus found at 2 min 22.44 sec
# Best chorus found at 1 min 8.51 sec
# Best chorus found at 2 min 56.46 sec
# Best chorus found at 2 min 48.03 sec
# Best chorus found at 2 min 13.36 sec
# Best chorus found at 3 min 0.85 sec
# Best chorus found at 2 min 48.96 sec
# Best chorus found at 3 min 58.95 sec
# Best chorus found at 2 min 32.80 sec
# Best chorus found at 1 min 41.18 sec
# Best chorus found at 2 min 58.39 sec
# Best chorus found at 1 min 14.65 sec
# Best chorus found at 2 min 0.48 sec
# Best chorus found at 2 min 2.72 sec
# Best chorus found at 2 min 5.54 sec
# Best chorus found at 1 min 53.05 sec
# Best chorus found at 1 min 22.26 sec
# Best chorus found at 2 min 32.81 sec
# Best chorus found at 1 min 52.69 sec
# Best chorus found at 2 min 6.39 sec
# Best chorus found at 2 min 19.09 sec
# Best chorus found at 2 min 2.89 sec
# Best chorus found at 0 min 34.36 sec
# Best chorus found at 5 min 18.67 sec
# Best chorus found at 2 min 30.18 sec
# Best chorus found at 1 min 23.93 sec
# Best chorus found at 3 min 3.20 sec
# Best chorus found at 2 min 49.89 sec
# Best chorus found at 3 min 40.02 sec
# Best chorus found at 5 min 9.07 sec
# Best chorus found at 1 min 56.04 sec
# Best chorus found at 2 min 49.76 sec
# Best chorus found at 2 min 26.34 sec
# No choruses were detected. Try a smaller search duration
# Best chorus found at 2 min 57.87 sec
# Best chorus found at 3 min 3.96 sec
# Best chorus found at 1 min 18.70 sec
# Best chorus found at 2 min 58.68 sec
# Best chorus found at 1 min 39.29 sec
# Best chorus found at 1 min 19.46 sec
# No choruses were detected. Try a smaller search duration
# Best chorus found at 1 min 36.90 sec
# Best chorus found at 2 min 22.65 sec
# Best chorus found at 1 min 13.92 sec
# Best chorus found at 2 min 42.91 sec
# Best chorus found at 3 min 40.08 sec
# Best chorus found at 2 min 1.78 sec
# Best chorus found at 2 min 31.29 sec
# Best chorus found at 4 min 13.47 sec
# Best chorus found at 3 min 5.30 sec
# Best chorus found at 2 min 21.47 sec
# Best chorus found at 2 min 57.15 sec
# Best chorus found at 2 min 45.04 sec
# Best chorus found at 0 min 51.57 sec
# Best chorus found at 1 min 12.39 sec
# Best chorus found at 2 min 25.42 sec
# Best chorus found at 2 min 5.37 sec
# Best chorus found at 2 min 17.57 sec
# Best chorus found at 2 min 32.48 sec
# Best chorus found at 1 min 29.12 sec
# Best chorus found at 3 min 45.10 sec
# Best chorus found at 0 min 48.66 sec
# Best chorus found at 3 min 18.82 sec
# Best chorus found at 1 min 19.07 sec
# Best chorus found at 3 min 12.81 sec
# Best chorus found at 2 min 50.52 sec
# Best chorus found at 3 min 3.51 sec
# Best chorus found at 2 min 55.13 sec
# Best chorus found at 3 min 11.14 sec
# Best chorus found at 2 min 34.72 sec
# Best chorus found at 1 min 20.56 sec
# Best chorus found at 3 min 5.80 sec
# Best chorus found at 1 min 43.44 sec
# Best chorus found at 2 min 43.15 sec
# Best chorus found at 3 min 23.52 sec
# Best chorus found at 2 min 24.12 sec
# Best chorus found at 3 min 46.71 sec
# Best chorus found at 2 min 59.01 sec
# Best chorus found at 2 min 41.05 sec
# Best chorus found at 3 min 15.53 sec
# Best chorus found at 3 min 27.98 sec
# Best chorus found at 2 min 24.81 sec
# Best chorus found at 2 min 34.92 sec
# Best chorus found at 1 min 57.49 sec
# Best chorus found at 1 min 28.03 sec
# Best chorus found at 3 min 12.01 sec
# Best chorus found at 2 min 37.71 sec
# Best chorus found at 3 min 1.91 sec
# Best chorus found at 2 min 18.35 sec
# Best chorus found at 11 min 33.94 sec
# Best chorus found at 1 min 7.98 sec
# Best chorus found at 1 min 35.10 sec
# Best chorus found at 3 min 27.42 sec
# Best chorus found at 3 min 27.85 sec
# Best chorus found at 2 min 44.69 sec
# Best chorus found at 2 min 26.64 sec
# Best chorus found at 2 min 43.91 sec
# Best chorus found at 1 min 25.38 sec
# No choruses were detected. Try a smaller search duration
# Best chorus found at 1 min 35.20 sec
# Best chorus found at 1 min 52.74 sec
# Best chorus found at 2 min 32.02 sec
# Best chorus found at 4 min 31.24 sec
# Best chorus found at 2 min 40.06 sec
# Best chorus found at 2 min 39.45 sec
# Best chorus found at 0 min 56.25 sec
# Best chorus found at 3 min 7.90 sec
# Best chorus found at 3 min 5.68 sec
# Best chorus found at 2 min 25.33 sec
# Best chorus found at 2 min 19.58 sec
# Best chorus found at 2 min 33.18 sec
# Best chorus found at 3 min 7.02 sec
# Best chorus found at 3 min 23.40 sec
# Best chorus found at 2 min 8.82 sec
# Best chorus found at 1 min 47.90 sec
# Best chorus found at 2 min 46.72 sec
# Best chorus found at 4 min 5.75 sec
# Best chorus found at 2 min 25.90 sec
# Best chorus found at 1 min 20.79 sec
# Best chorus found at 2 min 6.44 sec
# Best chorus found at 4 min 22.89 sec
# Best chorus found at 3 min 6.61 sec
# Best chorus found at 3 min 0.51 sec
# Best chorus found at 1 min 56.56 sec
# Best chorus found at 3 min 49.74 sec
# Best chorus found at 2 min 35.90 sec
# Best chorus found at 2 min 9.22 sec
# Best chorus found at 4 min 25.87 sec
# Best chorus found at 3 min 27.39 sec
# Best chorus found at 2 min 17.09 sec
# Best chorus found at 4 min 48.35 sec
# Best chorus found at 3 min 29.06 sec
# Best chorus found at 2 min 42.27 sec
# No choruses were detected. Try a smaller search duration
# Best chorus found at 3 min 1.29 sec
# Best chorus found at 2 min 6.96 sec
# Best chorus found at 6 min 38.48 sec
# Best chorus found at 3 min 5.49 sec
# Best chorus found at 4 min 3.22 sec
# Best chorus found at 3 min 58.55 sec
# Best chorus found at 2 min 11.26 sec
# Best chorus found at 2 min 50.00 sec
# Best chorus found at 2 min 53.97 sec
# Best chorus found at 2 min 43.60 sec
# Best chorus found at 3 min 52.83 sec
# Best chorus found at 2 min 22.65 sec
# Best chorus found at 1 min 34.68 sec
# Best chorus found at 5 min 12.24 sec
# Best chorus found at 3 min 40.61 sec
# Best chorus found at 2 min 47.35 sec
# Best chorus found at 3 min 29.48 sec
# Best chorus found at 2 min 56.71 sec
# No choruses were detected. Try a smaller search duration
# Best chorus found at 1 min 53.43 sec
# Best chorus found at 2 min 35.24 sec
# Best chorus found at 2 min 52.37 sec
# Best chorus found at 3 min 11.25 sec
# Best chorus found at 2 min 16.53 sec
# Best chorus found at 3 min 48.60 sec
# Best chorus found at 2 min 29.90 sec
# Best chorus found at 3 min 11.09 sec
# Best chorus found at 2 min 58.62 sec
# Best chorus found at 3 min 5.48 sec
# Best chorus found at 2 min 36.48 sec
# Best chorus found at 2 min 50.97 sec
# Best chorus found at 3 min 27.66 sec
# Best chorus found at 3 min 7.80 sec
# No choruses were detected. Try a smaller search duration
# Best chorus found at 1 min 57.18 sec
# Best chorus found at 5 min 31.08 sec
# Best chorus found at 11 min 45.02 sec
# Best chorus found at 1 min 21.52 sec
# Best chorus found at 2 min 35.07 sec
# Best chorus found at 4 min 33.40 sec
# Best chorus found at 2 min 54.16 sec
# Best chorus found at 1 min 25.02 sec
# Best chorus found at 2 min 57.91 sec
# Best chorus found at 3 min 21.63 sec
# Best chorus found at 1 min 32.49 sec
# Best chorus found at 2 min 7.41 sec
# Best chorus found at 4 min 12.87 sec
# No choruses were detected. Try a smaller search duration
# Best chorus found at 3 min 3.90 sec
# Best chorus found at 4 min 28.85 sec
# Best chorus found at 2 min 21.44 sec
# Best chorus found at 3 min 11.44 sec
# Best chorus found at 3 min 23.20 sec
# Best chorus found at 1 min 36.89 sec
# Best chorus found at 3 min 11.44 sec
# Best chorus found at 3 min 19.45 sec
# Best chorus found at 1 min 27.82 sec
# Best chorus found at 1 min 57.94 sec
# Best chorus found at 2 min 21.14 sec

# %%
len(not_extrated) # check total number of not extracted songs
# Out:
# 11

# %%
extracted_song_basename = [song.replace('.wav','') for song in os.listdir('Untitled Folder')] # get extracteds songs basename
extracted_song_list = [] # list for songs from table present in successful extraction list 
for song in df['song_path']:
    basename = os.path.basename(song).replace('.mp3','')
    if  basename in extracted_song_basename:
        extracted_song_list.append(f'/content/Untitled Folder/{basename}.wav') # append successfuly extracted songs to list
    else:
        extracted_song_list.append('n/a') # append not available if extracted song does not exist

# %%
len(extracted_song_list)
# Out:
# 481

# %%
df = df.assign(extracted_chorus_path=extracted_song_list) # add new exteacted chorus paths to data table 
df
# Out:
#              Artist             Title  Label  \
# 0        The Weeknd   Blinding Lights      1
# 1    Olivia Rodrigo          Good 4 U      1
# 2    Olivia Rodrigo   Drivers License      1
# 3               BTS            Butter      1
# 4    Olivia Rodrigo           Deja Vu      1
# ..              ...               ...    ...
# 477     Chris Brown             No BS      0
# 478     Nicki Minaj     Right Thru Me      0
# 479    Taylor Swift              Mine      0
# 480   Rascal Flatts          Why Wait      0
# 481        Coldplay  Christmas Lights      0
#
#                                              song_path  \
# 0    /content/Downloaded_Songs/Popular_Songs/Blindi...
# 1    /content/Downloaded_Songs/Popular_Songs/Good 4...
# 2    /content/Downloaded_Songs/Popular_Songs/Driver...
# 3    /content/Downloaded_Songs/Popular_Songs/Butter...
# 4    /content/Downloaded_Songs/Popular_Songs/Deja V...
# ..                                                 ...
# 477  /content/Downloaded_Songs/Unpopular_Songs/Did ...
# 478  /content/Downloaded_Songs/Unpopular_Songs/No B...
# 479  /content/Downloaded_Songs/Unpopular_Songs/Righ...
# 480  /content/Downloaded_Songs/Unpopular_Songs/Mine...
# 481  /content/Downloaded_Songs/Unpopular_Songs/Why ...
#
#                             extracted_chorus_path
# 0    /content/Untitled Folder/Blinding Lights.wav
# 1           /content/Untitled Folder/Good 4 U.wav
# 2    /content/Untitled Folder/Drivers License.wav
# 3             /content/Untitled Folder/Butter.wav
# 4            /content/Untitled Folder/Deja Vu.wav
# ..                                            ...
# 477     /content/Untitled Folder/Did It On'em.wav
# 478            /content/Untitled Folder/No BS.wav
# 479    /content/Untitled Folder/Right Thru Me.wav
# 480             /content/Untitled Folder/Mine.wav
# 481         /content/Untitled Folder/Why Wait.wav
#
# [481 rows x 5 columns]

# %%
#save table to csv file 
df.to_csv('extracted_chorus_incomplete.csv', index=False) # dataset with incomplete extracted choruses

# %%
data1 = pd.read_csv('extracted_chorus_incomplete.csv')
data1.isna().sum() # get total number of non available extracted paths
# Out:
# Artist                    0
# Title                     0
# Label                     0
# song_path                 0
# extracted_chorus_path    11
# dtype: int64

# %%
data1 = data1.dropna() # drop rows with non available extract path 
data1.isna().sum()
# Out:
# Artist                   0
# Title                    0
# Label                    0
# song_path                0
# extracted_chorus_path    0
# dtype: int64

# %%
#save table to csv file 
data1.to_csv('extracted_chorus.csv', index=False)

# %% [markdown]
# # **Extract audio features**
# major features to extract :
# - chroma_stft
# - chroma_cqt
# - chroma_cens
# - mfcc
# - rms
# - spectral_centroid
# - spectral_bandwidth
# - spectral_contrast
# - spectral_rolloff
# - tonnetz
# - zero_crossing_rate

# %%
# import necessary libraries
import numpy as np 
import pandas as pd 
import librosa 
from glob import glob
from scipy.stats import skew, kurtosis  # import libs for statistics

# %%
#load dataset 
import os
data = pd.read_csv('extracted_chorus.csv')
df = data.copy()
df
# Out:
#              Artist             Title  Label  \
# 0        The Weeknd   Blinding Lights      1
# 1    Olivia Rodrigo          Good 4 U      1
# 2    Olivia Rodrigo   Drivers License      1
# 3               BTS            Butter      1
# 4    Olivia Rodrigo           Deja Vu      1
# ..              ...               ...    ...
# 465     Chris Brown             No BS      0
# 466     Nicki Minaj     Right Thru Me      0
# 467    Taylor Swift              Mine      0
# 468   Rascal Flatts          Why Wait      0
# 469        Coldplay  Christmas Lights      0
#
#                                              song_path  \
# 0    /content/Downloaded_Songs/Popular_Songs/Blindi...
# 1    /content/Downloaded_Songs/Popular_Songs/Good 4...
# 2    /content/Downloaded_Songs/Popular_Songs/Driver...
# 3    /content/Downloaded_Songs/Popular_Songs/Butter...
# 4    /content/Downloaded_Songs/Popular_Songs/Deja V...
# ..                                                 ...
# 465  /content/Downloaded_Songs/Unpopular_Songs/Did ...
# 466  /content/Downloaded_Songs/Unpopular_Songs/No B...
# 467  /content/Downloaded_Songs/Unpopular_Songs/Righ...
# 468  /content/Downloaded_Songs/Unpopular_Songs/Mine...
# 469  /content/Downloaded_Songs/Unpopular_Songs/Why ...
#
#                             extracted_chorus_path
# 0    /content/Untitled Folder/Blinding Lights.wav
# 1           /content/Untitled Folder/Good 4 U.wav
# 2    /content/Untitled Folder/Drivers License.wav
# 3             /content/Untitled Folder/Butter.wav
# 4            /content/Untitled Folder/Deja Vu.wav
# ..                                            ...
# 465     /content/Untitled Folder/Did It On'em.wav
# 466            /content/Untitled Folder/No BS.wav
# 467    /content/Untitled Folder/Right Thru Me.wav
# 468             /content/Untitled Folder/Mine.wav
# 469         /content/Untitled Folder/Why Wait.wav
#
# [470 rows x 5 columns]

# %%
paths = list(df['extracted_chorus_path']) # list for extracted chorus paths
titles = list(df['Title']) # list of song titles
data = [] # list to contain extracted audio features

# %%
# helper function to get statistics of each dimension data for each audio raw feature 
def statistics(list, feature, columns_name, data):
    i = 0 # label to track the number of raw dimensions for each audio feature 
    for ele in list:
        # get the 7 statististics of each raw dimension
        _skew = skew(ele)
        columns_name.append(f'{feature}_kew_{i}')
        min = np.min(ele)
        columns_name.append(f'{feature}_min_{i}')
        max = np.max(ele)
        columns_name.append(f'{feature}_max_{i}')
        std = np.std(ele)
        columns_name.append(f'{feature}_std_{i}')
        mean = np.mean(ele)
        columns_name.append(f'{feature}_mean_{i}')
        median = np.median(ele)
        columns_name.append(f'{feature}_median_{i}')
        _kurtosis = kurtosis(ele)
        columns_name.append(f'{feature}_kurtosis_{i}')

        i += 1
        # append 7 statistics as single row in list 
        data.append(_skew) 
        data.append(min)
        data.append(max) 
        data.append(std) 
        data.append(mean) 
        data.append(median) 
        data.append(_kurtosis)
    
    return data

# %%
# helper function ectract audio feature with statistics 
def extract_features(audio_path, title):

    data = []
    columns_name = ['title']
    data.append(title)
    x , sr = librosa.load(audio_path) #load audio waveform and sample rate

    chroma_stft = librosa.feature.chroma_stft(x, sr) # chroma_stft with 12 raw dims
    statistics(chroma_stft, 'chroma_stft', columns_name, data) # stats = 12 dims * 7 stats data

    chroma_cqt = librosa.feature.chroma_cqt(x, sr) # chroma_cqt with 12 raw dims
    statistics(chroma_cqt, 'chroma_cqt', columns_name, data) # stats = 12 dims * 7 stats data

    chroma_cens = librosa.feature.chroma_cens(x, sr) # chroma_cens with 12 raw dims
    statistics(chroma_cens, 'chroma_cens', columns_name, data) # stats = 12 dims * 7 stats data

    mfcc = librosa.feature.mfcc(x, sr) # mfcc with 20 raw dims
    statistics(mfcc, 'mfcc', columns_name, data)  # stats = 20 dims * 7 stats data
    
    rms = librosa.feature.rms(x, sr) # rms with 1 raw dims
    statistics(rms, 'rms', columns_name, data) # stats = 1 dims * 7 stats data

    spectral_centroid = librosa.feature.spectral_centroid(x , sr) # spectral_centroid with 1 raw dims
    statistics(spectral_centroid, 'spectral_centroid', columns_name, data) # stats = 1 dims * 7 stats data

    spectral_bandwidth = librosa.feature.spectral_bandwidth(x , sr) # spectral_bandwidth with 1 raw dims
    statistics(spectral_bandwidth, 'spectral_bandwidth', columns_name, data) # stats = 1 dims * 7 stats data

    spectral_contrast = librosa.feature.spectral_contrast(x , sr) # spectral_contrast with 7 raw dims
    statistics(spectral_contrast, 'spectral_contrast', columns_name, data) # stats = 7 dims * 7 stats data
    
    spectral_rolloff = librosa.feature.spectral_rolloff(x , sr) # spectral_rolloff with 1 raw dims
    statistics(spectral_rolloff, 'spectral_rolloff', columns_name, data) # stats = 1 dims * 7 stats data

    tonnetz = librosa.feature.tonnetz(x , sr) # tonnetz with 6 raw dims
    statistics(tonnetz, 'tonnetz', columns_name, data) # stats = 6 dims * 7 stats data

    zero_crossing_rate = librosa.feature.zero_crossing_rate(x , sr) # zero_crossing_rate with 1 raw dims
    statistics(zero_crossing_rate, 'zero_crossing_rate', columns_name, data) # stats = 1 dims * 7 stats data

    # total number of expected dimensions - 518

    return data, columns_name

# %%
# extract audio freatures for all songs chosuses/Hook
i = 0
while i < len(paths):
    audio_path = paths[i]
    d, cols = extract_features(audio_path, titles[i])
    data.append(d)
    print(f'The {i} song Done...')
    i += 1
# Out:
# The 0 song Done...
# The 1 song Done...
# The 2 song Done...
# The 3 song Done...
# The 4 song Done...
# The 5 song Done...
# The 6 song Done...
# The 7 song Done...
# The 8 song Done...
# The 9 song Done...
# The 10 song Done...
# The 11 song Done...
# The 12 song Done...
# The 13 song Done...
# The 14 song Done...
# The 15 song Done...
# The 16 song Done...
# The 17 song Done...
# The 18 song Done...
# The 19 song Done...
# The 20 song Done...
# The 21 song Done...
# The 22 song Done...
# The 23 song Done...
# The 24 song Done...
# The 25 song Done...
# The 26 song Done...
# The 27 song Done...
# The 28 song Done...
# The 29 song Done...
# The 30 song Done...
# The 31 song Done...
# The 32 song Done...
# The 33 song Done...
# The 34 song Done...
# The 35 song Done...
# The 36 song Done...
# The 37 song Done...
# The 38 song Done...
# The 39 song Done...
# The 40 song Done...
# The 41 song Done...
# The 42 song Done...
# The 43 song Done...
# The 44 song Done...
# The 45 song Done...
# The 46 song Done...
# The 47 song Done...
# The 48 song Done...
# The 49 song Done...
# The 50 song Done...
# The 51 song Done...
# The 52 song Done...
# The 53 song Done...
# The 54 song Done...
# The 55 song Done...
# The 56 song Done...
# The 57 song Done...
# The 58 song Done...
# The 59 song Done...
# The 60 song Done...
# The 61 song Done...
# The 62 song Done...
# The 63 song Done...
# The 64 song Done...
# The 65 song Done...
# The 66 song Done...
# The 67 song Done...
# The 68 song Done...
# The 69 song Done...
# The 70 song Done...
# The 71 song Done...
# The 72 song Done...
# The 73 song Done...
# The 74 song Done...
# The 75 song Done...
# The 76 song Done...
# The 77 song Done...
# The 78 song Done...
# The 79 song Done...
# The 80 song Done...
# The 81 song Done...
# The 82 song Done...
# The 83 song Done...
# The 84 song Done...
# The 85 song Done...
# The 86 song Done...
# The 87 song Done...
# The 88 song Done...
# The 89 song Done...
# The 90 song Done...
# The 91 song Done...
# The 92 song Done...
# The 93 song Done...
# The 94 song Done...
# The 95 song Done...
# The 96 song Done...
# The 97 song Done...
# The 98 song Done...
# The 99 song Done...
# The 100 song Done...
# The 101 song Done...
# The 102 song Done...
# The 103 song Done...
# The 104 song Done...
# The 105 song Done...
# The 106 song Done...
# The 107 song Done...
# The 108 song Done...
# The 109 song Done...
# The 110 song Done...
# The 111 song Done...
# The 112 song Done...
# The 113 song Done...
# The 114 song Done...
# The 115 song Done...
# The 116 song Done...
# The 117 song Done...
# The 118 song Done...
# The 119 song Done...
# The 120 song Done...
# The 121 song Done...
# The 122 song Done...
# The 123 song Done...
# The 124 song Done...
# The 125 song Done...
# The 126 song Done...
# The 127 song Done...
# The 128 song Done...
# The 129 song Done...
# The 130 song Done...
# The 131 song Done...
# The 132 song Done...
# The 133 song Done...
# The 134 song Done...
# The 135 song Done...
# The 136 song Done...
# The 137 song Done...
# The 138 song Done...
# The 139 song Done...
# The 140 song Done...
# The 141 song Done...
# The 142 song Done...
# The 143 song Done...
# The 144 song Done...
# The 145 song Done...
# The 146 song Done...
# The 147 song Done...
# The 148 song Done...
# The 149 song Done...
# The 150 song Done...
# The 151 song Done...
# The 152 song Done...
# The 153 song Done...
# The 154 song Done...
# The 155 song Done...
# The 156 song Done...
# The 157 song Done...
# The 158 song Done...
# The 159 song Done...
# The 160 song Done...
# The 161 song Done...
# The 162 song Done...
# The 163 song Done...
# The 164 song Done...
# The 165 song Done...
# The 166 song Done...
# The 167 song Done...
# The 168 song Done...
# The 169 song Done...
# The 170 song Done...
# The 171 song Done...
# The 172 song Done...
# The 173 song Done...
# The 174 song Done...
# The 175 song Done...
# The 176 song Done...
# The 177 song Done...
# The 178 song Done...
# The 179 song Done...
# The 180 song Done...
# The 181 song Done...
# The 182 song Done...
# The 183 song Done...
# The 184 song Done...
# The 185 song Done...
# The 186 song Done...
# The 187 song Done...
# The 188 song Done...
# The 189 song Done...
# The 190 song Done...
# The 191 song Done...
# The 192 song Done...
# The 193 song Done...
# The 194 song Done...
# The 195 song Done...
# The 196 song Done...
# The 197 song Done...
# The 198 song Done...
# The 199 song Done...
# The 200 song Done...
# The 201 song Done...
# The 202 song Done...
# The 203 song Done...
# The 204 song Done...
# The 205 song Done...
# The 206 song Done...
# The 207 song Done...
# The 208 song Done...
# The 209 song Done...
# The 210 song Done...
# The 211 song Done...
# The 212 song Done...
# The 213 song Done...
# The 214 song Done...
# The 215 song Done...
# The 216 song Done...
# The 217 song Done...
# The 218 song Done...
# The 219 song Done...
# The 220 song Done...
# The 221 song Done...
# The 222 song Done...
# The 223 song Done...
# The 224 song Done...
# The 225 song Done...
# The 226 song Done...
# The 227 song Done...
# The 228 song Done...
# The 229 song Done...
# The 230 song Done...
# The 231 song Done...
# The 232 song Done...
# The 233 song Done...
# The 234 song Done...
# The 235 song Done...
# The 236 song Done...
# The 237 song Done...
# The 238 song Done...
# The 239 song Done...
# The 240 song Done...
# The 241 song Done...
# The 242 song Done...
# The 243 song Done...
# The 244 song Done...
# The 245 song Done...
# The 246 song Done...
# The 247 song Done...
# The 248 song Done...
# The 249 song Done...
# The 250 song Done...
# The 251 song Done...
# The 252 song Done...
# The 253 song Done...
# The 254 song Done...
# The 255 song Done...
# The 256 song Done...
# The 257 song Done...
# The 258 song Done...
# The 259 song Done...
# The 260 song Done...
# The 261 song Done...
# The 262 song Done...
# The 263 song Done...
# The 264 song Done...
# The 265 song Done...
# The 266 song Done...
# The 267 song Done...
# The 268 song Done...
# The 269 song Done...
# The 270 song Done...
# The 271 song Done...
# The 272 song Done...
# The 273 song Done...
# The 274 song Done...
# The 275 song Done...
# The 276 song Done...
# The 277 song Done...
# The 278 song Done...
# The 279 song Done...
# The 280 song Done...
# The 281 song Done...
# The 282 song Done...
# The 283 song Done...
# The 284 song Done...
# The 285 song Done...
# The 286 song Done...
# The 287 song Done...
# The 288 song Done...
# The 289 song Done...
# The 290 song Done...
# The 291 song Done...
# The 292 song Done...
# The 293 song Done...
# The 294 song Done...
# The 295 song Done...
# The 296 song Done...
# The 297 song Done...
# The 298 song Done...
# The 299 song Done...
# The 300 song Done...
# The 301 song Done...
# The 302 song Done...
# The 303 song Done...
# The 304 song Done...
# The 305 song Done...
# The 306 song Done...
# The 307 song Done...
# The 308 song Done...
# The 309 song Done...
# The 310 song Done...
# The 311 song Done...
# The 312 song Done...
# The 313 song Done...
# The 314 song Done...
# The 315 song Done...
# The 316 song Done...
# The 317 song Done...
# The 318 song Done...
# The 319 song Done...
# The 320 song Done...
# The 321 song Done...
# The 322 song Done...
# The 323 song Done...
# The 324 song Done...
# The 325 song Done...
# The 326 song Done...
# The 327 song Done...
# The 328 song Done...
# The 329 song Done...
# The 330 song Done...
# The 331 song Done...
# The 332 song Done...
# The 333 song Done...
# The 334 song Done...
# The 335 song Done...
# The 336 song Done...
# The 337 song Done...
# The 338 song Done...
# The 339 song Done...
# The 340 song Done...
# The 341 song Done...
# The 342 song Done...
# The 343 song Done...
# The 344 song Done...
# The 345 song Done...
# The 346 song Done...
# The 347 song Done...
# The 348 song Done...
# The 349 song Done...
# The 350 song Done...
# The 351 song Done...
# The 352 song Done...
# The 353 song Done...
# The 354 song Done...
# The 355 song Done...
# The 356 song Done...
# The 357 song Done...
# The 358 song Done...
# The 359 song Done...
# The 360 song Done...
# The 361 song Done...
# The 362 song Done...
# The 363 song Done...
# The 364 song Done...
# The 365 song Done...
# The 366 song Done...
# The 367 song Done...
# The 368 song Done...
# The 369 song Done...
# The 370 song Done...
# The 371 song Done...
# The 372 song Done...
# The 373 song Done...
# The 374 song Done...
# The 375 song Done...
# The 376 song Done...
# The 377 song Done...
# The 378 song Done...
# The 379 song Done...
# The 380 song Done...
# The 381 song Done...
# The 382 song Done...
# The 383 song Done...
# The 384 song Done...
# The 385 song Done...
# The 386 song Done...
# The 387 song Done...
# The 388 song Done...
# The 389 song Done...
# The 390 song Done...
# The 391 song Done...
# The 392 song Done...
# The 393 song Done...
# The 394 song Done...
# The 395 song Done...
# The 396 song Done...
# The 397 song Done...
# The 398 song Done...
# The 399 song Done...
# The 400 song Done...
# The 401 song Done...
# The 402 song Done...
# The 403 song Done...
# The 404 song Done...
# The 405 song Done...
# The 406 song Done...
# The 407 song Done...
# The 408 song Done...
# The 409 song Done...
# The 410 song Done...
# The 411 song Done...
# The 412 song Done...
# The 413 song Done...
# The 414 song Done...
# The 415 song Done...
# The 416 song Done...
# The 417 song Done...
# The 418 song Done...
# The 419 song Done...
# The 420 song Done...
# The 421 song Done...
# The 422 song Done...
# The 423 song Done...
# The 424 song Done...
# The 425 song Done...
# The 426 song Done...
# The 427 song Done...
# The 428 song Done...
# The 429 song Done...
# The 430 song Done...
# The 431 song Done...
# The 432 song Done...
# The 433 song Done...
# The 434 song Done...
# The 435 song Done...
# The 436 song Done...
# The 437 song Done...
# The 438 song Done...
# The 439 song Done...
# The 440 song Done...
# The 441 song Done...
# The 442 song Done...
# The 443 song Done...
# The 444 song Done...
# The 445 song Done...
# The 446 song Done...
# The 447 song Done...
# The 448 song Done...
# The 449 song Done...
# The 450 song Done...
# The 451 song Done...
# The 452 song Done...
# The 453 song Done...
# The 454 song Done...
# The 455 song Done...
# The 456 song Done...
# The 457 song Done...
# The 458 song Done...
# The 459 song Done...
# The 460 song Done...
# The 461 song Done...
# The 462 song Done...
# The 463 song Done...
# The 464 song Done...
# The 465 song Done...
# The 466 song Done...
# The 467 song Done...
# The 468 song Done...
# The 469 song Done...

# %%
newData = pd.DataFrame(data, columns=cols) # create dataframe for new extracted audio features 
newData
# Out:
#                 title  chroma_stft_kew_0  chroma_stft_min_0  \
# 0     Blinding Lights           0.476192           0.016697
# 1            Good 4 U           1.048281           0.006909
# 2     Drivers License           1.399714           0.000636
# 3              Butter           0.299845           0.036609
# 4             Deja Vu           0.437894           0.000988
# ..                ...                ...                ...
# 465             No BS          -0.612871           0.042869
# 466     Right Thru Me           0.894951           0.009010
# 467              Mine           0.457498           0.046513
# 468          Why Wait           1.401094           0.029235
# 469  Christmas Lights           2.177790           0.009197
#
#      chroma_stft_max_0  chroma_stft_std_0  chroma_stft_mean_0  \
# 0             1.000000           0.290165            0.473183
# 1             1.000000           0.274690            0.347730
# 2             1.000000           0.307648            0.236694
# 3             1.000000           0.334760            0.521782
# 4             1.000000           0.309152            0.470539
# ..                 ...                ...                 ...
# 465           1.000000           0.248398            0.741888
# 466           0.947567           0.173043            0.280782
# 467           1.000000           0.287367            0.509159
# 468           1.000000           0.212190            0.292161
# 469           1.000000           0.171141            0.174238
#
#      chroma_stft_median_0  chroma_stft_kurtosis_0  chroma_stft_kew_1  \
# 0                0.422056               -0.920438           0.742264
# 1                0.255082                0.136358           0.299100
# 2                0.088057                0.757593           1.642706
# 3                0.451320               -1.433215           0.839978
# 4                0.399200               -1.032645          -0.122870
# ..                    ...                     ...                ...
# 465              0.794269               -0.799252           0.064605
# 466              0.243074                0.597739           1.600044
# 467              0.425283               -1.001521          -0.236815
# 468              0.232873                1.734134           0.879865
# 469              0.121675                5.768343           1.560135
#
#      chroma_stft_min_1  ...  tonnetz_mean_5  tonnetz_median_5  \
# 0             0.015519  ...        0.007436          0.000934
# 1             0.004950  ...       -0.010380         -0.011803
# 2             0.000449  ...       -0.000745         -0.010594
# 3             0.049554  ...        0.006860          0.004859
# 4             0.001615  ...        0.025928          0.017413
# ..                 ...  ...             ...               ...
# 465           0.063076  ...       -0.045943         -0.042724
# 466           0.005850  ...        0.000169          0.009414
# 467           0.018313  ...       -0.039237         -0.034262
# 468           0.023444  ...       -0.013460         -0.014324
# 469           0.028226  ...        0.009420          0.009158
#
#      tonnetz_kurtosis_5  zero_crossing_rate_kew_0  zero_crossing_rate_min_0  \
# 0             -0.539747                  1.466814                  0.037551
# 1              0.115312                 -0.398137                  0.054286
# 2              0.422336                  0.783507                  0.022902
# 3             -0.384372                  2.536822                  0.040181
# 4              4.609701                  0.940449                  0.055329
# ..                  ...                       ...                       ...
# 465           -0.383369                  0.429500                  0.021043
# 466            0.258497                  0.620365                  0.020000
# 467           -0.040045                 -0.133719                  0.064263
# 468           -0.608029                 -0.901050                  0.068571
# 469           -0.083342                 -0.631882                  0.057732
#
#      zero_crossing_rate_max_0  zero_crossing_rate_std_0  \
# 0                    0.159229                  0.020931
# 1                    0.224626                  0.035255
# 2                    0.175873                  0.031743
# 3                    0.221769                  0.027223
# 4                    0.180454                  0.025201
# ..                        ...                       ...
# 465                  0.139773                  0.028834
# 466                  0.063583                  0.010984
# 467                  0.140408                  0.015389
# 468                  0.204853                  0.025302
# 469                  0.183220                  0.021021
#
#      zero_crossing_rate_mean_0  zero_crossing_rate_median_0  \
# 0                     0.082646                     0.079751
# 1                     0.147474                     0.157392
# 2                     0.076301                     0.065442
# 3                     0.095766                     0.090703
# 4                     0.105715                     0.100136
# ..                         ...                          ...
# 465                   0.069132                     0.068095
# 466                   0.040461                     0.036689
# 467                   0.112145                     0.110975
# 468                   0.162091                     0.163968
# 469                   0.133799                     0.134966
#
#      zero_crossing_rate_kurtosis_0
# 0                         3.242503
# 1                        -0.313862
# 2                        -0.074665
# 3                         7.626171
# 4                         0.687683
# ..                             ...
# 465                      -0.524287
# 466                      -0.890274
# 467                      -0.672546
# 468                       0.846849
# 469                       1.168150
#
# [470 rows x 519 columns]

# %%
df # previous data table
# Out:
#              Artist             Title  Label  \
# 0        The Weeknd   Blinding Lights      1
# 1    Olivia Rodrigo          Good 4 U      1
# 2    Olivia Rodrigo   Drivers License      1
# 3               BTS            Butter      1
# 4    Olivia Rodrigo           Deja Vu      1
# ..              ...               ...    ...
# 465     Chris Brown             No BS      0
# 466     Nicki Minaj     Right Thru Me      0
# 467    Taylor Swift              Mine      0
# 468   Rascal Flatts          Why Wait      0
# 469        Coldplay  Christmas Lights      0
#
#                                              song_path  \
# 0    /content/Downloaded_Songs/Popular_Songs/Blindi...
# 1    /content/Downloaded_Songs/Popular_Songs/Good 4...
# 2    /content/Downloaded_Songs/Popular_Songs/Driver...
# 3    /content/Downloaded_Songs/Popular_Songs/Butter...
# 4    /content/Downloaded_Songs/Popular_Songs/Deja V...
# ..                                                 ...
# 465  /content/Downloaded_Songs/Unpopular_Songs/Did ...
# 466  /content/Downloaded_Songs/Unpopular_Songs/No B...
# 467  /content/Downloaded_Songs/Unpopular_Songs/Righ...
# 468  /content/Downloaded_Songs/Unpopular_Songs/Mine...
# 469  /content/Downloaded_Songs/Unpopular_Songs/Why ...
#
#                             extracted_chorus_path
# 0    /content/Untitled Folder/Blinding Lights.wav
# 1           /content/Untitled Folder/Good 4 U.wav
# 2    /content/Untitled Folder/Drivers License.wav
# 3             /content/Untitled Folder/Butter.wav
# 4            /content/Untitled Folder/Deja Vu.wav
# ..                                            ...
# 465     /content/Untitled Folder/Did It On'em.wav
# 466            /content/Untitled Folder/No BS.wav
# 467    /content/Untitled Folder/Right Thru Me.wav
# 468             /content/Untitled Folder/Mine.wav
# 469         /content/Untitled Folder/Why Wait.wav
#
# [470 rows x 5 columns]

# %%
final_data = df.join(newData) # join both datasets of same number of rows 
final_data
# Out:
#              Artist             Title  Label  \
# 0        The Weeknd   Blinding Lights      1
# 1    Olivia Rodrigo          Good 4 U      1
# 2    Olivia Rodrigo   Drivers License      1
# 3               BTS            Butter      1
# 4    Olivia Rodrigo           Deja Vu      1
# ..              ...               ...    ...
# 465     Chris Brown             No BS      0
# 466     Nicki Minaj     Right Thru Me      0
# 467    Taylor Swift              Mine      0
# 468   Rascal Flatts          Why Wait      0
# 469        Coldplay  Christmas Lights      0
#
#                                              song_path  \
# 0    /content/Downloaded_Songs/Popular_Songs/Blindi...
# 1    /content/Downloaded_Songs/Popular_Songs/Good 4...
# 2    /content/Downloaded_Songs/Popular_Songs/Driver...
# 3    /content/Downloaded_Songs/Popular_Songs/Butter...
# 4    /content/Downloaded_Songs/Popular_Songs/Deja V...
# ..                                                 ...
# 465  /content/Downloaded_Songs/Unpopular_Songs/Did ...
# 466  /content/Downloaded_Songs/Unpopular_Songs/No B...
# 467  /content/Downloaded_Songs/Unpopular_Songs/Righ...
# 468  /content/Downloaded_Songs/Unpopular_Songs/Mine...
# 469  /content/Downloaded_Songs/Unpopular_Songs/Why ...
#
#                             extracted_chorus_path             title  \
# 0    /content/Untitled Folder/Blinding Lights.wav   Blinding Lights
# 1           /content/Untitled Folder/Good 4 U.wav          Good 4 U
# 2    /content/Untitled Folder/Drivers License.wav   Drivers License
# 3             /content/Untitled Folder/Butter.wav            Butter
# 4            /content/Untitled Folder/Deja Vu.wav           Deja Vu
# ..                                            ...               ...
# 465     /content/Untitled Folder/Did It On'em.wav             No BS
# 466            /content/Untitled Folder/No BS.wav     Right Thru Me
# 467    /content/Untitled Folder/Right Thru Me.wav              Mine
# 468             /content/Untitled Folder/Mine.wav          Why Wait
# 469         /content/Untitled Folder/Why Wait.wav  Christmas Lights
#
#      chroma_stft_kew_0  chroma_stft_min_0  chroma_stft_max_0  \
# 0             0.476192           0.016697           1.000000
# 1             1.048281           0.006909           1.000000
# 2             1.399714           0.000636           1.000000
# 3             0.299845           0.036609           1.000000
# 4             0.437894           0.000988           1.000000
# ..                 ...                ...                ...
# 465          -0.612871           0.042869           1.000000
# 466           0.894951           0.009010           0.947567
# 467           0.457498           0.046513           1.000000
# 468           1.401094           0.029235           1.000000
# 469           2.177790           0.009197           1.000000
#
#      chroma_stft_std_0  ...  tonnetz_mean_5  tonnetz_median_5  \
# 0             0.290165  ...        0.007436          0.000934
# 1             0.274690  ...       -0.010380         -0.011803
# 2             0.307648  ...       -0.000745         -0.010594
# 3             0.334760  ...        0.006860          0.004859
# 4             0.309152  ...        0.025928          0.017413
# ..                 ...  ...             ...               ...
# 465           0.248398  ...       -0.045943         -0.042724
# 466           0.173043  ...        0.000169          0.009414
# 467           0.287367  ...       -0.039237         -0.034262
# 468           0.212190  ...       -0.013460         -0.014324
# 469           0.171141  ...        0.009420          0.009158
#
#      tonnetz_kurtosis_5  zero_crossing_rate_kew_0  zero_crossing_rate_min_0  \
# 0             -0.539747                  1.466814                  0.037551
# 1              0.115312                 -0.398137                  0.054286
# 2              0.422336                  0.783507                  0.022902
# 3             -0.384372                  2.536822                  0.040181
# 4              4.609701                  0.940449                  0.055329
# ..                  ...                       ...                       ...
# 465           -0.383369                  0.429500                  0.021043
# 466            0.258497                  0.620365                  0.020000
# 467           -0.040045                 -0.133719                  0.064263
# 468           -0.608029                 -0.901050                  0.068571
# 469           -0.083342                 -0.631882                  0.057732
#
#      zero_crossing_rate_max_0  zero_crossing_rate_std_0  \
# 0                    0.159229                  0.020931
# 1                    0.224626                  0.035255
# 2                    0.175873                  0.031743
# 3                    0.221769                  0.027223
# 4                    0.180454                  0.025201
# ..                        ...                       ...
# 465                  0.139773                  0.028834
# 466                  0.063583                  0.010984
# 467                  0.140408                  0.015389
# 468                  0.204853                  0.025302
# 469                  0.183220                  0.021021
#
#      zero_crossing_rate_mean_0  zero_crossing_rate_median_0  \
# 0                     0.082646                     0.079751
# 1                     0.147474                     0.157392
# 2                     0.076301                     0.065442
# 3                     0.095766                     0.090703
# 4                     0.105715                     0.100136
# ..                         ...                          ...
# 465                   0.069132                     0.068095
# 466                   0.040461                     0.036689
# 467                   0.112145                     0.110975
# 468                   0.162091                     0.163968
# 469                   0.133799                     0.134966
#
#      zero_crossing_rate_kurtosis_0
# 0                         3.242503
# 1                        -0.313862
# 2                        -0.074665
# 3                         7.626171
# 4                         0.687683
# ..                             ...
# 465                      -0.524287
# 466                      -0.890274
# 467                      -0.672546
# 468                       0.846849
# 469                       1.168150
#
# [470 rows x 524 columns]

# %%
final_data.columns # scan for repeated column names
# Out:
# Index(['Artist', 'Title', 'Label', 'song_path', 'extracted_chorus_path',
#        'title', 'chroma_stft_kew_0', 'chroma_stft_min_0', 'chroma_stft_max_0',
#        'chroma_stft_std_0',
#        ...
#        'tonnetz_mean_5', 'tonnetz_median_5', 'tonnetz_kurtosis_5',
#        'zero_crossing_rate_kew_0', 'zero_crossing_rate_min_0',
#        'zero_crossing_rate_max_0', 'zero_crossing_rate_std_0',
#        'zero_crossing_rate_mean_0', 'zero_crossing_rate_median_0',
#        'zero_crossing_rate_kurtosis_0'],
#       dtype='object', length=524)

# %%
final_data = final_data.drop(columns=['title'], axis=1) #drop repeated colunm name

# %%
final_data.columns
# Out:
# Index(['Artist', 'Title', 'Label', 'song_path', 'extracted_chorus_path',
#        'chroma_stft_kew_0', 'chroma_stft_min_0', 'chroma_stft_max_0',
#        'chroma_stft_std_0', 'chroma_stft_mean_0',
#        ...
#        'tonnetz_mean_5', 'tonnetz_median_5', 'tonnetz_kurtosis_5',
#        'zero_crossing_rate_kew_0', 'zero_crossing_rate_min_0',
#        'zero_crossing_rate_max_0', 'zero_crossing_rate_std_0',
#        'zero_crossing_rate_mean_0', 'zero_crossing_rate_median_0',
#        'zero_crossing_rate_kurtosis_0'],
#       dtype='object', length=523)

# %%
#save table to csv file 
final_data.to_csv('feature_extract.csv', index=False)
